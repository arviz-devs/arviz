# %%
# --[plot_compare, plot_dist, plot_rank, plot_kde, plot_khat, plot_energy[only kind=density], plot_autocorr]--

# %%
import arviz as az
from arviz.data import load_arviz_data
from arviz.plots import plot_compare,plot_dist, plot_energy
from line_profiler import LineProfiler
import numpy as np

# %%
school = load_arviz_data("centered_eight")
nschool = load_arviz_data("non_centered_eight")
compare_dict = {"1":school,"2":nschool}

# %%
pd = az.stats.compare(compare_dict)

# %%
plot_compare(pd)

# %%
lp = LineProfiler()
wrapper = lp(plot_compare)
wrapper(pd)
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.108246 s
# File: /home/banzee/Desktop/arviz/arviz/plots/compareplot.py
# Function: plot_compare at line 7
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      7                                           def plot_compare(
#      8                                               comp_df,
#      9                                               insample_dev=True,
#     10                                               plot_standard_error=True,
#     11                                               plot_ic_diff=True,
#     12                                               figsize=None,
#     13                                               textsize=None,
#     14                                               plot_kwargs=None,
#     15                                               ax=None,
#     16                                           ):
#     17                                               """
#     18                                               Summary plot for model comparison.
#     19
#     20                                               This plot is in the style of the one used in the book Statistical Rethinking (Chapter 6)
#     21                                               by Richard McElreath.
#     22
#     23                                               Notes
#     24                                               -----
#     25                                               Defaults to comparing Widely Accepted Information Criterion (WAIC) if present in comp_df column,
#     26                                               otherwise compares Leave-one-out (loo)
#     27
#     28
#     29                                               Parameters
#     30                                               ----------
#     31                                               comp_df: pd.DataFrame
#     32                                                   Result of the `az.compare()` method
#     33                                               insample_dev : bool, optional
#     34                                                   Plot in-sample deviance, that is the value of the information criteria without the
#     35                                                   penalization given by the effective number of parameters (pIC). Defaults to True
#     36                                               plot_standard_error : bool, optional
#     37                                                   Plot the standard error of the information criteria estimate. Defaults to True
#     38                                               plot_ic_diff : bool, optional
#     39                                                   Plot standard error of the difference in information criteria between each model
#     40                                                    and the top-ranked model. Defaults to True
#     41                                               figsize : tuple, optional
#     42                                                   If None, size is (6, num of models) inches
#     43                                               textsize: float
#     44                                                   Text size scaling factor for labels, titles and lines. If None it will be autoscaled based
#     45                                                   on figsize.
#     46                                               plot_kwargs : dict, optional
#     47                                                   Optional arguments for plot elements. Currently accepts 'color_ic',
#     48                                                   'marker_ic', 'color_insample_dev', 'marker_insample_dev', 'color_dse',
#     49                                                   'marker_dse', 'ls_min_ic' 'color_ls_min_ic',  'fontsize'
#     50                                               ax : axes, optional
#     51                                                   Matplotlib axes
#     52
#     53                                               Returns
#     54                                               -------
#     55                                               ax : matplotlib axes
#     56
#     57
#     58                                               Examples
#     59                                               --------
#     60                                               Show default compare plot
#     61
#     62                                               .. plot::
#     63                                                   :context: close-figs
#     64
#     65                                                   >>> import arviz as az
#     66                                                   >>> model_compare = az.compare({'Centered 8 schools': az.load_arviz_data('centered_eight'),
#     67                                                   >>>                  'Non-centered 8 schools': az.load_arviz_data('non_centered_eight')})
#     68                                                   >>> az.plot_compare(model_compare)
#     69
#     70                                               Plot standard error and information criteria difference only
#     71
#     72                                               .. plot::
#     73                                                   :context: close-figs
#     74
#     75                                                   >>> az.plot_compare(model_compare, insample_dev=False)
#     76
#     77                                               """
#     78         1          8.0      8.0      0.0      if figsize is None:
#     79         1         38.0     38.0      0.0          figsize = (6, len(comp_df))
#     80
#     81         1        131.0    131.0      0.1      figsize, ax_labelsize, _, xt_labelsize, linewidth, _ = _scale_fig_size(figsize, textsize, 1, 1)
#     82
#     83         1          6.0      6.0      0.0      if ax is None:
#     84         1      59459.0  59459.0     54.9          _, ax = plt.subplots(figsize=figsize, constrained_layout=True)
#     85
#     86         1          3.0      3.0      0.0      if plot_kwargs is None:
#     87         1          2.0      2.0      0.0          plot_kwargs = {}
#     88
#     89         1        136.0    136.0      0.1      yticks_pos, step = np.linspace(0, -1, (comp_df.shape[0] * 2) - 1, retstep=True)
#     90         1         14.0     14.0      0.0      yticks_pos[1::2] = yticks_pos[1::2] + step / 2
#     91
#     92         1          3.0      3.0      0.0      yticks_labels = [""] * len(yticks_pos)
#     93
#     94         1          2.0      2.0      0.0      _information_criterion = ["waic", "loo"]
#     95         1          2.0      2.0      0.0      for information_criterion in _information_criterion:
#     96         1         12.0     12.0      0.0          if information_criterion in comp_df.columns:
#     97         1          3.0      3.0      0.0              break
#     98                                               else:
#     99                                                   raise ValueError(
#    100                                                       "comp_df must contain one of the following"
#    101                                                       " information criterion: {}".format(_information_criterion)
#    102                                                   )
#    103
#    104         1          2.0      2.0      0.0      if plot_ic_diff:
#    105         1         18.0     18.0      0.0          yticks_labels[0] = comp_df.index[0]
#    106         1        164.0    164.0      0.2          yticks_labels[2::2] = comp_df.index[1:]
#    107         1       2832.0   2832.0      2.6          ax.set_yticks(yticks_pos)
#    108         1          4.0      4.0      0.0          ax.errorbar(
#    109         1        415.0    415.0      0.4              x=comp_df[information_criterion].iloc[1:],
#    110         1          4.0      4.0      0.0              y=yticks_pos[1::2],
#    111         1        507.0    507.0      0.5              xerr=comp_df.dse[1:],
#    112         1          5.0      5.0      0.0              color=plot_kwargs.get("color_dse", "grey"),
#    113         1          2.0      2.0      0.0              fmt=plot_kwargs.get("marker_dse", "^"),
#    114         1          2.0      2.0      0.0              mew=linewidth,
#    115         1      19244.0  19244.0     17.8              elinewidth=linewidth,
#    116                                                   )
#    117
#    118                                               else:
#    119                                                   yticks_labels = comp_df.index
#    120                                                   ax.set_yticks(yticks_pos[::2])
#    121
#    122         1          7.0      7.0      0.0      if plot_standard_error:
#    123         1          5.0      5.0      0.0          ax.errorbar(
#    124         1         57.0     57.0      0.1              x=comp_df[information_criterion],
#    125         1          9.0      9.0      0.0              y=yticks_pos[::2],
#    126         1         82.0     82.0      0.1              xerr=comp_df.se,
#    127         1          7.0      7.0      0.0              color=plot_kwargs.get("color_ic", "k"),
#    128         1          6.0      6.0      0.0              fmt=plot_kwargs.get("marker_ic", "o"),
#    129         1          5.0      5.0      0.0              mfc="None",
#    130         1          6.0      6.0      0.0              mew=linewidth,
#    131         1      12594.0  12594.0     11.6              lw=linewidth,
#    132                                                   )
#    133                                               else:
#    134                                                   ax.plot(
#    135                                                       comp_df[information_criterion],
#    136                                                       yticks_pos[::2],
#    137                                                       color=plot_kwargs.get("color_ic", "k"),
#    138                                                       marker=plot_kwargs.get("marker_ic", "o"),
#    139                                                       mfc="None",
#    140                                                       mew=linewidth,
#    141                                                       lw=0,
#    142                                                   )
#    143
#    144         1          5.0      5.0      0.0      if insample_dev:
#    145         1          3.0      3.0      0.0          ax.plot(
#    146         1       1669.0   1669.0      1.5              comp_df[information_criterion] - (2 * comp_df["p_" + information_criterion]),
#    147         1         10.0     10.0      0.0              yticks_pos[::2],
#    148         1          7.0      7.0      0.0              color=plot_kwargs.get("color_insample_dev", "k"),
#    149         1          4.0      4.0      0.0              marker=plot_kwargs.get("marker_insample_dev", "o"),
#    150         1          3.0      3.0      0.0              mew=linewidth,
#    151         1       5177.0   5177.0      4.8              lw=0,
#    152                                                   )
#    153
#    154         1          5.0      5.0      0.0      ax.axvline(
#    155         1        155.0    155.0      0.1          comp_df[information_criterion].iloc[0],
#    156         1          4.0      4.0      0.0          ls=plot_kwargs.get("ls_min_ic", "--"),
#    157         1          3.0      3.0      0.0          color=plot_kwargs.get("color_ls_min_ic", "grey"),
#    158         1       3576.0   3576.0      3.3          lw=linewidth,
#    159                                               )
#    160
#    161         1          4.0      4.0      0.0      scale_col = information_criterion + "_scale"
#    162         1         23.0     23.0      0.0      if scale_col in comp_df:
#    163         1        132.0    132.0      0.1          scale = comp_df[scale_col].iloc[0].capitalize()
#    164                                               else:
#    165                                                   scale = "Deviance"
#    166         1         95.0     95.0      0.1      ax.set_xlabel(scale, fontsize=ax_labelsize)
#    167         1        175.0    175.0      0.2      ax.set_yticklabels(yticks_labels)
#    168         1        365.0    365.0      0.3      ax.set_ylim(-1 + step, 0 - step)
#    169         1       1032.0   1032.0      1.0      ax.tick_params(labelsize=xt_labelsize)
#    170
#    171         1          3.0      3.0      0.0      return ax

# %%
#All matplotlib bottlenecks,not ideal for numba

# %%
"""""""""""""""""""""""""""""""""""""""""""""DISTPLOT"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
# Out:
# 'DISTPLOT'

# %%
data = np.random.randn(10000,1000)
school = load_arviz_data("centered_eight").posterior["mu"].values

# %%
lp = LineProfiler()
wrapper = lp(plot_dist)
wrapper(data, kind='density')
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 4.20084 s
# File: /home/banzee/Desktop/arviz/arviz/plots/distplot.py
# Function: plot_dist at line 8
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      8                                           def plot_dist(
#      9                                               values,
#     10                                               values2=None,
#     11                                               color="C0",
#     12                                               kind="auto",
#     13                                               cumulative=False,
#     14                                               label=None,
#     15                                               rotated=False,
#     16                                               rug=False,
#     17                                               bw=4.5,
#     18                                               quantiles=None,
#     19                                               contour=True,
#     20                                               fill_last=True,
#     21                                               textsize=None,
#     22                                               plot_kwargs=None,
#     23                                               fill_kwargs=None,
#     24                                               rug_kwargs=None,
#     25                                               contour_kwargs=None,
#     26                                               hist_kwargs=None,
#     27                                               ax=None,
#     28                                           ):
#     29                                               """Plot distribution as histogram or kernel density estimates.
#     30
#     31                                               By default continuous variables are plotted using KDEs and discrete ones using histograms
#     32
#     33                                               Parameters
#     34                                               ----------
#     35                                               values : array-like
#     36                                                   Values to plot
#     37                                               values2 : array-like, optional
#     38                                                   Values to plot. If present, a 2D KDE or a hexbin will be estimated
#     39                                               color : string
#     40                                                   valid matplotlib color
#     41                                               kind : string
#     42                                                   By default ("auto") continuous variables are plotted using KDEs and discrete ones using
#     43                                                   histograms. To override this use "hist" to plot histograms and "density" for KDEs
#     44                                               cumulative : bool
#     45                                                   If true plot the estimated cumulative distribution function. Defaults to False.
#     46                                                   Ignored for 2D KDE
#     47                                               label : string
#     48                                                   Text to include as part of the legend
#     49                                               rotated : bool
#     50                                                   Whether to rotate the 1D KDE plot 90 degrees.
#     51                                               rug : bool
#     52                                                   If True adds a rugplot. Defaults to False. Ignored for 2D KDE
#     53                                               bw : float
#     54                                                   Bandwidth scaling factor for 1D KDE. Should be larger than 0. The higher this number the
#     55                                                   smoother the KDE will be. Defaults to 4.5 which is essentially the same as the Scott's
#     56                                                   rule of thumb (the default rule used by SciPy).
#     57                                               quantiles : list
#     58                                                   Quantiles in ascending order used to segment the KDE. Use [.25, .5, .75] for quartiles.
#     59                                                   Defaults to None.
#     60                                               contour : bool
#     61                                                   If True plot the 2D KDE using contours, otherwise plot a smooth 2D KDE. Defaults to True.
#     62                                               fill_last : bool
#     63                                                   If True fill the last contour of the 2D KDE plot. Defaults to True.
#     64                                               textsize: float
#     65                                                   Text size scaling factor for labels, titles and lines. If None it will be autoscaled based
#     66                                                   on figsize.
#     67                                               plot_kwargs : dict
#     68                                                   Keywords passed to the pdf line of a 1D KDE.
#     69                                               fill_kwargs : dict
#     70                                                   Keywords passed to the fill under the line (use fill_kwargs={'alpha': 0} to disable fill).
#     71                                                   Ignored for 2D KDE
#     72                                               rug_kwargs : dict
#     73                                                   Keywords passed to the rug plot. Ignored if rug=False or for 2D KDE
#     74                                                   Use `space` keyword (float) to control the position of the rugplot. The larger this number
#     75                                                   the lower the rugplot.
#     76                                               contour_kwargs : dict
#     77                                                   Keywords passed to the contourplot. Ignored for 1D KDE.
#     78                                               hist_kwargs : dict
#     79                                                   Keywords passed to the histogram.
#     80                                               ax : matplotlib axes
#     81
#     82                                               Returns
#     83                                               -------
#     84                                               ax : matplotlib axes
#     85                                               """
#     86         1          5.0      5.0      0.0      if ax is None:
#     87         1      38846.0  38846.0      0.9          ax = plt.gca()
#     88
#     89         1          3.0      3.0      0.0      if hist_kwargs is None:
#     90         1          1.0      1.0      0.0          hist_kwargs = {}
#     91         1          2.0      2.0      0.0      hist_kwargs.setdefault("bins", None)
#     92         1         10.0     10.0      0.0      hist_kwargs.setdefault("cumulative", cumulative)
#     93         1          1.0      1.0      0.0      hist_kwargs.setdefault("color", color)
#     94         1          2.0      2.0      0.0      hist_kwargs.setdefault("label", label)
#     95         1          2.0      2.0      0.0      hist_kwargs.setdefault("rwidth", 0.9)
#     96         1          2.0      2.0      0.0      hist_kwargs.setdefault("align", "left")
#     97         1          2.0      2.0      0.0      hist_kwargs.setdefault("density", True)
#     98
#     99         1          2.0      2.0      0.0      if plot_kwargs is None:
#    100         1          1.0      1.0      0.0          plot_kwargs = {}
#    101
#    102         1          1.0      1.0      0.0      if rotated:
#    103                                                   hist_kwargs.setdefault("orientation", "horizontal")
#    104                                               else:
#    105         1          2.0      2.0      0.0          hist_kwargs.setdefault("orientation", "vertical")
#    106
#    107         1          2.0      2.0      0.0      if kind == "auto":
#    108                                                   kind = "hist" if values.dtype.kind == "i" else "density"
#    109
#    110         1          4.0      4.0      0.0      if kind == "hist":
#    111                                                   _histplot_op(
#    112                                                       values=values, values2=values2, rotated=rotated, ax=ax, hist_kwargs=hist_kwargs
#    113                                                   )
#    114         1          2.0      2.0      0.0      elif kind == "density":
#    115         1          1.0      1.0      0.0          plot_kwargs.setdefault("color", color)
#    116         1          2.0      2.0      0.0          legend = label is not None
#    117
#    118         1          1.0      1.0      0.0          plot_kde(
#    119         1          1.0      1.0      0.0              values,
#    120         1          1.0      1.0      0.0              values2,
#    121         1          2.0      2.0      0.0              cumulative=cumulative,
#    122         1          2.0      2.0      0.0              rug=rug,
#    123         1          1.0      1.0      0.0              label=label,
#    124         1          1.0      1.0      0.0              bw=bw,
#    125         1          1.0      1.0      0.0              quantiles=quantiles,
#    126         1          2.0      2.0      0.0              rotated=rotated,
#    127         1          2.0      2.0      0.0              contour=contour,
#    128         1          1.0      1.0      0.0              legend=legend,
#    129         1          1.0      1.0      0.0              fill_last=fill_last,
#    130         1          1.0      1.0      0.0              textsize=textsize,
#    131         1          2.0      2.0      0.0              plot_kwargs=plot_kwargs,
#    132         1          1.0      1.0      0.0              fill_kwargs=fill_kwargs,
#    133         1          1.0      1.0      0.0              rug_kwargs=rug_kwargs,
#    134         1          1.0      1.0      0.0              contour_kwargs=contour_kwargs,
#    135         1    4161922.0 4161922.0     99.1              ax=ax,
#    136                                                   )
#    137         1          5.0      5.0      0.0      return ax

# %%
lp = LineProfiler()
wrapper = lp(plot_dist)
wrapper(school, kind='density')
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.082154 s
# File: /home/banzee/Desktop/arviz/arviz/plots/distplot.py
# Function: plot_dist at line 8
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      8                                           def plot_dist(
#      9                                               values,
#     10                                               values2=None,
#     11                                               color="C0",
#     12                                               kind="auto",
#     13                                               cumulative=False,
#     14                                               label=None,
#     15                                               rotated=False,
#     16                                               rug=False,
#     17                                               bw=4.5,
#     18                                               quantiles=None,
#     19                                               contour=True,
#     20                                               fill_last=True,
#     21                                               textsize=None,
#     22                                               plot_kwargs=None,
#     23                                               fill_kwargs=None,
#     24                                               rug_kwargs=None,
#     25                                               contour_kwargs=None,
#     26                                               hist_kwargs=None,
#     27                                               ax=None,
#     28                                           ):
#     29                                               """Plot distribution as histogram or kernel density estimates.
#     30
#     31                                               By default continuous variables are plotted using KDEs and discrete ones using histograms
#     32
#     33                                               Parameters
#     34                                               ----------
#     35                                               values : array-like
#     36                                                   Values to plot
#     37                                               values2 : array-like, optional
#     38                                                   Values to plot. If present, a 2D KDE or a hexbin will be estimated
#     39                                               color : string
#     40                                                   valid matplotlib color
#     41                                               kind : string
#     42                                                   By default ("auto") continuous variables are plotted using KDEs and discrete ones using
#     43                                                   histograms. To override this use "hist" to plot histograms and "density" for KDEs
#     44                                               cumulative : bool
#     45                                                   If true plot the estimated cumulative distribution function. Defaults to False.
#     46                                                   Ignored for 2D KDE
#     47                                               label : string
#     48                                                   Text to include as part of the legend
#     49                                               rotated : bool
#     50                                                   Whether to rotate the 1D KDE plot 90 degrees.
#     51                                               rug : bool
#     52                                                   If True adds a rugplot. Defaults to False. Ignored for 2D KDE
#     53                                               bw : float
#     54                                                   Bandwidth scaling factor for 1D KDE. Should be larger than 0. The higher this number the
#     55                                                   smoother the KDE will be. Defaults to 4.5 which is essentially the same as the Scott's
#     56                                                   rule of thumb (the default rule used by SciPy).
#     57                                               quantiles : list
#     58                                                   Quantiles in ascending order used to segment the KDE. Use [.25, .5, .75] for quartiles.
#     59                                                   Defaults to None.
#     60                                               contour : bool
#     61                                                   If True plot the 2D KDE using contours, otherwise plot a smooth 2D KDE. Defaults to True.
#     62                                               fill_last : bool
#     63                                                   If True fill the last contour of the 2D KDE plot. Defaults to True.
#     64                                               textsize: float
#     65                                                   Text size scaling factor for labels, titles and lines. If None it will be autoscaled based
#     66                                                   on figsize.
#     67                                               plot_kwargs : dict
#     68                                                   Keywords passed to the pdf line of a 1D KDE.
#     69                                               fill_kwargs : dict
#     70                                                   Keywords passed to the fill under the line (use fill_kwargs={'alpha': 0} to disable fill).
#     71                                                   Ignored for 2D KDE
#     72                                               rug_kwargs : dict
#     73                                                   Keywords passed to the rug plot. Ignored if rug=False or for 2D KDE
#     74                                                   Use `space` keyword (float) to control the position of the rugplot. The larger this number
#     75                                                   the lower the rugplot.
#     76                                               contour_kwargs : dict
#     77                                                   Keywords passed to the contourplot. Ignored for 1D KDE.
#     78                                               hist_kwargs : dict
#     79                                                   Keywords passed to the histogram.
#     80                                               ax : matplotlib axes
#     81
#     82                                               Returns
#     83                                               -------
#     84                                               ax : matplotlib axes
#     85                                               """
#     86         1          6.0      6.0      0.0      if ax is None:
#     87         1      70062.0  70062.0     85.3          ax = plt.gca()
#     88
#     89         1          2.0      2.0      0.0      if hist_kwargs is None:
#     90         1          2.0      2.0      0.0          hist_kwargs = {}
#     91         1          2.0      2.0      0.0      hist_kwargs.setdefault("bins", None)
#     92         1          2.0      2.0      0.0      hist_kwargs.setdefault("cumulative", cumulative)
#     93         1          2.0      2.0      0.0      hist_kwargs.setdefault("color", color)
#     94         1          2.0      2.0      0.0      hist_kwargs.setdefault("label", label)
#     95         1          1.0      1.0      0.0      hist_kwargs.setdefault("rwidth", 0.9)
#     96         1          2.0      2.0      0.0      hist_kwargs.setdefault("align", "left")
#     97         1          2.0      2.0      0.0      hist_kwargs.setdefault("density", True)
#     98
#     99         1          2.0      2.0      0.0      if plot_kwargs is None:
#    100         1          2.0      2.0      0.0          plot_kwargs = {}
#    101
#    102         1          1.0      1.0      0.0      if rotated:
#    103                                                   hist_kwargs.setdefault("orientation", "horizontal")
#    104                                               else:
#    105         1          1.0      1.0      0.0          hist_kwargs.setdefault("orientation", "vertical")
#    106
#    107         1          2.0      2.0      0.0      if kind == "auto":
#    108                                                   kind = "hist" if values.dtype.kind == "i" else "density"
#    109
#    110         1          1.0      1.0      0.0      if kind == "hist":
#    111                                                   _histplot_op(
#    112                                                       values=values, values2=values2, rotated=rotated, ax=ax, hist_kwargs=hist_kwargs
#    113                                                   )
#    114         1          1.0      1.0      0.0      elif kind == "density":
#    115         1          2.0      2.0      0.0          plot_kwargs.setdefault("color", color)
#    116         1          2.0      2.0      0.0          legend = label is not None
#    117
#    118         1          2.0      2.0      0.0          plot_kde(
#    119         1          1.0      1.0      0.0              values,
#    120         1          1.0      1.0      0.0              values2,
#    121         1          1.0      1.0      0.0              cumulative=cumulative,
#    122         1          1.0      1.0      0.0              rug=rug,
#    123         1          2.0      2.0      0.0              label=label,
#    124         1          2.0      2.0      0.0              bw=bw,
#    125         1          2.0      2.0      0.0              quantiles=quantiles,
#    126         1          2.0      2.0      0.0              rotated=rotated,
#    127         1          2.0      2.0      0.0              contour=contour,
#    128         1          1.0      1.0      0.0              legend=legend,
#    129         1          1.0      1.0      0.0              fill_last=fill_last,
#    130         1          1.0      1.0      0.0              textsize=textsize,
#    131         1          1.0      1.0      0.0              plot_kwargs=plot_kwargs,
#    132         1          2.0      2.0      0.0              fill_kwargs=fill_kwargs,
#    133         1          2.0      2.0      0.0              rug_kwargs=rug_kwargs,
#    134         1          2.0      2.0      0.0              contour_kwargs=contour_kwargs,
#    135         1      12025.0  12025.0     14.6              ax=ax,
#    136                                                   )
#    137         1          4.0      4.0      0.0      return ax

# %%
# %timeit plot_dist(data, kind='density')
# Out:
# 245 ms ± 26.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit plot_dist(data, kind='density')
# Out:
# 349 ms ± 64.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
#Bottleneck == plot_kde.

# %%
###################################################Energy plot##########################################################

# %%
radon = load_arviz_data('radon')
school = load_arviz_data('centered_eight')

# %%
radon
# Out:
# Inference data with groups:
# 	> posterior
# 	> sample_stats
# 	> posterior_predictive
# 	> prior
# 	> observed_data

# %%
school
# Out:
# Inference data with groups:
# 	> posterior
# 	> sample_stats
# 	> posterior_predictive
# 	> prior
# 	> observed_data

# %%
lp = LineProfiler()
wrapper = lp(plot_energy)
wrapper(school, kind='kde')
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.314798 s
# File: /home/banzee/Desktop/arviz/arviz/plots/energyplot.py
# Function: plot_energy at line 10
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     10                                           def plot_energy(
#     11                                               data,
#     12                                               kind="kde",
#     13                                               bfmi=True,
#     14                                               figsize=None,
#     15                                               legend=True,
#     16                                               fill_alpha=(1, 0.75),
#     17                                               fill_color=("C0", "C5"),
#     18                                               bw=4.5,
#     19                                               textsize=None,
#     20                                               fill_kwargs=None,
#     21                                               plot_kwargs=None,
#     22                                               ax=None,
#     23                                           ):
#     24                                               """Plot energy transition distribution and marginal energy distribution in HMC algorithms.
#     25
#     26                                               This may help to diagnose poor exploration by gradient-based algorithms like HMC or NUTS.
#     27
#     28                                               Parameters
#     29                                               ----------
#     30                                               data : xarray dataset, or object that can be converted (must represent
#     31                                                      `sample_stats` and have an `energy` variable)
#     32                                               kind : str
#     33                                                   Type of plot to display (kde or histogram)
#     34                                               bfmi : bool
#     35                                                   If True add to the plot the value of the estimated Bayesian fraction of missing information
#     36                                               figsize : tuple
#     37                                                   Figure size. If None it will be defined automatically.
#     38                                               legend : bool
#     39                                                   Flag for plotting legend (defaults to True)
#     40                                               fill_alpha : tuple of floats
#     41                                                   Alpha blending value for the shaded area under the curve, between 0
#     42                                                   (no shade) and 1 (opaque). Defaults to (1, .75)
#     43                                               fill_color : tuple of valid matplotlib color
#     44                                                   Color for Marginal energy distribution and Energy transition distribution.
#     45                                                   Defaults to ('C0', 'C5')
#     46                                               bw : float
#     47                                                   Bandwidth scaling factor for the KDE. Should be larger than 0. The higher this number the
#     48                                                   smoother the KDE will be. Defaults to 4.5 which is essentially the same as the Scott's rule
#     49                                                   of thumb (the default rule used by SciPy). Only works if `kind='kde'`
#     50                                               textsize: float
#     51                                                   Text size scaling factor for labels, titles and lines. If None it will be autoscaled based
#     52                                                   on figsize.
#     53                                               fill_kwargs : dicts, optional
#     54                                                   Additional keywords passed to `arviz.plot_kde` (to control the shade)
#     55                                               plot_kwargs : dicts, optional
#     56                                                   Additional keywords passed to `arviz.plot_kde` or `plt.hist` (if type='hist')
#     57                                               ax : axes
#     58                                                   Matplotlib axes.
#     59
#     60                                               Returns
#     61                                               -------
#     62                                               ax : matplotlib axes
#     63
#     64                                               Examples
#     65                                               --------
#     66                                               Plot a default energy plot
#     67
#     68                                               .. plot::
#     69                                                   :context: close-figs
#     70
#     71                                                   >>> import arviz as az
#     72                                                   >>> data = az.load_arviz_data('centered_eight')
#     73                                                   >>> az.plot_energy(data)
#     74
#     75                                               Represent energy plot via histograms
#     76
#     77                                               .. plot::
#     78                                                   :context: close-figs
#     79
#     80                                                   >>> az.plot_energy(data, kind='hist')
#     81
#     82                                               """
#     83         1     137722.0 137722.0     43.7      energy = convert_to_dataset(data, group="sample_stats").energy.values
#     84
#     85         1         11.0     11.0      0.0      if ax is None:
#     86         1     101479.0 101479.0     32.2          _, ax = plt.subplots(figsize=figsize, constrained_layout=True)
#     87
#     88         1          8.0      8.0      0.0      if fill_kwargs is None:
#     89         1          5.0      5.0      0.0          fill_kwargs = {}
#     90
#     91         1          4.0      4.0      0.0      if plot_kwargs is None:
#     92         1          5.0      5.0      0.0          plot_kwargs = {}
#     93
#     94         1        141.0    141.0      0.0      figsize, _, _, xt_labelsize, linewidth, _ = _scale_fig_size(figsize, textsize, 1, 1)
#     95
#     96         1          6.0      6.0      0.0      series = zip(
#     97         1          5.0      5.0      0.0          fill_alpha,
#     98         1          5.0      5.0      0.0          fill_color,
#     99         1          5.0      5.0      0.0          ("Marginal Energy", "Energy transition"),
#    100         1        289.0    289.0      0.1          (energy - energy.mean(), np.diff(energy)),
#    101                                               )
#    102
#    103         1          6.0      6.0      0.0      if kind == "kde":
#    104         3         17.0      5.7      0.0          for alpha, color, label, value in series:
#    105         2         10.0      5.0      0.0              fill_kwargs["alpha"] = alpha
#    106         2          7.0      3.5      0.0              fill_kwargs["color"] = color
#    107         2         12.0      6.0      0.0              plot_kwargs.setdefault("color", color)
#    108         2          9.0      4.5      0.0              plot_kwargs.setdefault("alpha", 0)
#    109         2          9.0      4.5      0.0              plot_kwargs.setdefault("linewidth", linewidth)
#    110         2          8.0      4.0      0.0              plot_kde(
#    111         2          7.0      3.5      0.0                  value,
#    112         2          7.0      3.5      0.0                  bw=bw,
#    113         2          6.0      3.0      0.0                  label=label,
#    114         2          7.0      3.5      0.0                  textsize=xt_labelsize,
#    115         2          8.0      4.0      0.0                  fill_kwargs=fill_kwargs,
#    116         2          6.0      3.0      0.0                  plot_kwargs=plot_kwargs,
#    117         2          6.0      3.0      0.0                  ax=ax,
#    118         2      33148.0  16574.0     10.5                  legend=False,
#    119                                                       )
#    120                                               elif kind == "hist":
#    121                                                   for alpha, color, label, value in series:
#    122                                                       ax.hist(
#    123                                                           value.flatten(),
#    124                                                           bins="auto",
#    125                                                           density=True,
#    126                                                           alpha=alpha,
#    127                                                           label=label,
#    128                                                           color=color,
#    129                                                           **plot_kwargs
#    130                                                       )
#    131
#    132                                               else:
#    133                                                   raise ValueError("Plot type {} not recognized.".format(kind))
#    134
#    135         1          2.0      2.0      0.0      if bfmi:
#    136         5        284.0     56.8      0.1          for idx, val in enumerate(e_bfmi(energy)):
#    137         4      21469.0   5367.2      6.8              ax.plot([], label="chain {:>2} BFMI = {:.2f}".format(idx, val), alpha=0)
#    138         1          3.0      3.0      0.0      if legend:
#    139         1      19901.0  19901.0      6.3          ax.legend()
#    140
#    141         1        112.0    112.0      0.0      ax.set_xticks([])
#    142         1         67.0     67.0      0.0      ax.set_yticks([])
#    143
#    144         1          2.0      2.0      0.0      return ax

# %%
lp = LineProfiler()
wrapper = lp(plot_energy)
wrapper(radon, kind='kde')
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.138537 s
# File: /home/banzee/Desktop/arviz/arviz/plots/energyplot.py
# Function: plot_energy at line 10
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     10                                           def plot_energy(
#     11                                               data,
#     12                                               kind="kde",
#     13                                               bfmi=True,
#     14                                               figsize=None,
#     15                                               legend=True,
#     16                                               fill_alpha=(1, 0.75),
#     17                                               fill_color=("C0", "C5"),
#     18                                               bw=4.5,
#     19                                               textsize=None,
#     20                                               fill_kwargs=None,
#     21                                               plot_kwargs=None,
#     22                                               ax=None,
#     23                                           ):
#     24                                               """Plot energy transition distribution and marginal energy distribution in HMC algorithms.
#     25
#     26                                               This may help to diagnose poor exploration by gradient-based algorithms like HMC or NUTS.
#     27
#     28                                               Parameters
#     29                                               ----------
#     30                                               data : xarray dataset, or object that can be converted (must represent
#     31                                                      `sample_stats` and have an `energy` variable)
#     32                                               kind : str
#     33                                                   Type of plot to display (kde or histogram)
#     34                                               bfmi : bool
#     35                                                   If True add to the plot the value of the estimated Bayesian fraction of missing information
#     36                                               figsize : tuple
#     37                                                   Figure size. If None it will be defined automatically.
#     38                                               legend : bool
#     39                                                   Flag for plotting legend (defaults to True)
#     40                                               fill_alpha : tuple of floats
#     41                                                   Alpha blending value for the shaded area under the curve, between 0
#     42                                                   (no shade) and 1 (opaque). Defaults to (1, .75)
#     43                                               fill_color : tuple of valid matplotlib color
#     44                                                   Color for Marginal energy distribution and Energy transition distribution.
#     45                                                   Defaults to ('C0', 'C5')
#     46                                               bw : float
#     47                                                   Bandwidth scaling factor for the KDE. Should be larger than 0. The higher this number the
#     48                                                   smoother the KDE will be. Defaults to 4.5 which is essentially the same as the Scott's rule
#     49                                                   of thumb (the default rule used by SciPy). Only works if `kind='kde'`
#     50                                               textsize: float
#     51                                                   Text size scaling factor for labels, titles and lines. If None it will be autoscaled based
#     52                                                   on figsize.
#     53                                               fill_kwargs : dicts, optional
#     54                                                   Additional keywords passed to `arviz.plot_kde` (to control the shade)
#     55                                               plot_kwargs : dicts, optional
#     56                                                   Additional keywords passed to `arviz.plot_kde` or `plt.hist` (if type='hist')
#     57                                               ax : axes
#     58                                                   Matplotlib axes.
#     59
#     60                                               Returns
#     61                                               -------
#     62                                               ax : matplotlib axes
#     63
#     64                                               Examples
#     65                                               --------
#     66                                               Plot a default energy plot
#     67
#     68                                               .. plot::
#     69                                                   :context: close-figs
#     70
#     71                                                   >>> import arviz as az
#     72                                                   >>> data = az.load_arviz_data('centered_eight')
#     73                                                   >>> az.plot_energy(data)
#     74
#     75                                               Represent energy plot via histograms
#     76
#     77                                               .. plot::
#     78                                                   :context: close-figs
#     79
#     80                                                   >>> az.plot_energy(data, kind='hist')
#     81
#     82                                               """
#     83         1      33525.0  33525.0     24.2      energy = convert_to_dataset(data, group="sample_stats").energy.values
#     84
#     85         1          6.0      6.0      0.0      if ax is None:
#     86         1      53318.0  53318.0     38.5          _, ax = plt.subplots(figsize=figsize, constrained_layout=True)
#     87
#     88         1          3.0      3.0      0.0      if fill_kwargs is None:
#     89         1          2.0      2.0      0.0          fill_kwargs = {}
#     90
#     91         1          2.0      2.0      0.0      if plot_kwargs is None:
#     92         1          1.0      1.0      0.0          plot_kwargs = {}
#     93
#     94         1         54.0     54.0      0.0      figsize, _, _, xt_labelsize, linewidth, _ = _scale_fig_size(figsize, textsize, 1, 1)
#     95
#     96         1          2.0      2.0      0.0      series = zip(
#     97         1          2.0      2.0      0.0          fill_alpha,
#     98         1          2.0      2.0      0.0          fill_color,
#     99         1          1.0      1.0      0.0          ("Marginal Energy", "Energy transition"),
#    100         1        151.0    151.0      0.1          (energy - energy.mean(), np.diff(energy)),
#    101                                               )
#    102
#    103         1          3.0      3.0      0.0      if kind == "kde":
#    104         3         13.0      4.3      0.0          for alpha, color, label, value in series:
#    105         2          4.0      2.0      0.0              fill_kwargs["alpha"] = alpha
#    106         2          4.0      2.0      0.0              fill_kwargs["color"] = color
#    107         2          6.0      3.0      0.0              plot_kwargs.setdefault("color", color)
#    108         2          4.0      2.0      0.0              plot_kwargs.setdefault("alpha", 0)
#    109         2          4.0      2.0      0.0              plot_kwargs.setdefault("linewidth", linewidth)
#    110         2          4.0      2.0      0.0              plot_kde(
#    111         2          2.0      1.0      0.0                  value,
#    112         2          4.0      2.0      0.0                  bw=bw,
#    113         2          3.0      1.5      0.0                  label=label,
#    114         2          3.0      1.5      0.0                  textsize=xt_labelsize,
#    115         2          3.0      1.5      0.0                  fill_kwargs=fill_kwargs,
#    116         2          4.0      2.0      0.0                  plot_kwargs=plot_kwargs,
#    117         2          3.0      1.5      0.0                  ax=ax,
#    118         2      19211.0   9605.5     13.9                  legend=False,
#    119                                                       )
#    120                                               elif kind == "hist":
#    121                                                   for alpha, color, label, value in series:
#    122                                                       ax.hist(
#    123                                                           value.flatten(),
#    124                                                           bins="auto",
#    125                                                           density=True,
#    126                                                           alpha=alpha,
#    127                                                           label=label,
#    128                                                           color=color,
#    129                                                           **plot_kwargs
#    130                                                       )
#    131
#    132                                               else:
#    133                                                   raise ValueError("Plot type {} not recognized.".format(kind))
#    134
#    135         1          2.0      2.0      0.0      if bfmi:
#    136         5        291.0     58.2      0.2          for idx, val in enumerate(e_bfmi(energy)):
#    137         4      15395.0   3848.8     11.1              ax.plot([], label="chain {:>2} BFMI = {:.2f}".format(idx, val), alpha=0)
#    138         1          2.0      2.0      0.0      if legend:
#    139         1      16258.0  16258.0     11.7          ax.legend()
#    140
#    141         1        125.0    125.0      0.1      ax.set_xticks([])
#    142         1        115.0    115.0      0.1      ax.set_yticks([])
#    143
#    144         1          5.0      5.0      0.0      return ax

# %%
lp = LineProfiler()
wrapper = lp(plot_energy)
wrapper(radon, kind='hist')
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.422212 s
# File: /home/banzee/Desktop/arviz/arviz/plots/energyplot.py
# Function: plot_energy at line 10
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     10                                           def plot_energy(
#     11                                               data,
#     12                                               kind="kde",
#     13                                               bfmi=True,
#     14                                               figsize=None,
#     15                                               legend=True,
#     16                                               fill_alpha=(1, 0.75),
#     17                                               fill_color=("C0", "C5"),
#     18                                               bw=4.5,
#     19                                               textsize=None,
#     20                                               fill_kwargs=None,
#     21                                               plot_kwargs=None,
#     22                                               ax=None,
#     23                                           ):
#     24                                               """Plot energy transition distribution and marginal energy distribution in HMC algorithms.
#     25
#     26                                               This may help to diagnose poor exploration by gradient-based algorithms like HMC or NUTS.
#     27
#     28                                               Parameters
#     29                                               ----------
#     30                                               data : xarray dataset, or object that can be converted (must represent
#     31                                                      `sample_stats` and have an `energy` variable)
#     32                                               kind : str
#     33                                                   Type of plot to display (kde or histogram)
#     34                                               bfmi : bool
#     35                                                   If True add to the plot the value of the estimated Bayesian fraction of missing information
#     36                                               figsize : tuple
#     37                                                   Figure size. If None it will be defined automatically.
#     38                                               legend : bool
#     39                                                   Flag for plotting legend (defaults to True)
#     40                                               fill_alpha : tuple of floats
#     41                                                   Alpha blending value for the shaded area under the curve, between 0
#     42                                                   (no shade) and 1 (opaque). Defaults to (1, .75)
#     43                                               fill_color : tuple of valid matplotlib color
#     44                                                   Color for Marginal energy distribution and Energy transition distribution.
#     45                                                   Defaults to ('C0', 'C5')
#     46                                               bw : float
#     47                                                   Bandwidth scaling factor for the KDE. Should be larger than 0. The higher this number the
#     48                                                   smoother the KDE will be. Defaults to 4.5 which is essentially the same as the Scott's rule
#     49                                                   of thumb (the default rule used by SciPy). Only works if `kind='kde'`
#     50                                               textsize: float
#     51                                                   Text size scaling factor for labels, titles and lines. If None it will be autoscaled based
#     52                                                   on figsize.
#     53                                               fill_kwargs : dicts, optional
#     54                                                   Additional keywords passed to `arviz.plot_kde` (to control the shade)
#     55                                               plot_kwargs : dicts, optional
#     56                                                   Additional keywords passed to `arviz.plot_kde` or `plt.hist` (if type='hist')
#     57                                               ax : axes
#     58                                                   Matplotlib axes.
#     59
#     60                                               Returns
#     61                                               -------
#     62                                               ax : matplotlib axes
#     63
#     64                                               Examples
#     65                                               --------
#     66                                               Plot a default energy plot
#     67
#     68                                               .. plot::
#     69                                                   :context: close-figs
#     70
#     71                                                   >>> import arviz as az
#     72                                                   >>> data = az.load_arviz_data('centered_eight')
#     73                                                   >>> az.plot_energy(data)
#     74
#     75                                               Represent energy plot via histograms
#     76
#     77                                               .. plot::
#     78                                                   :context: close-figs
#     79
#     80                                                   >>> az.plot_energy(data, kind='hist')
#     81
#     82                                               """
#     83         1       1580.0   1580.0      0.4      energy = convert_to_dataset(data, group="sample_stats").energy.values
#     84
#     85         1          6.0      6.0      0.0      if ax is None:
#     86         1      77344.0  77344.0     18.3          _, ax = plt.subplots(figsize=figsize, constrained_layout=True)
#     87
#     88         1          6.0      6.0      0.0      if fill_kwargs is None:
#     89         1          5.0      5.0      0.0          fill_kwargs = {}
#     90
#     91         1          5.0      5.0      0.0      if plot_kwargs is None:
#     92         1          5.0      5.0      0.0          plot_kwargs = {}
#     93
#     94         1        410.0    410.0      0.1      figsize, _, _, xt_labelsize, linewidth, _ = _scale_fig_size(figsize, textsize, 1, 1)
#     95
#     96         1          6.0      6.0      0.0      series = zip(
#     97         1          4.0      4.0      0.0          fill_alpha,
#     98         1          5.0      5.0      0.0          fill_color,
#     99         1          4.0      4.0      0.0          ("Marginal Energy", "Energy transition"),
#    100         1        233.0    233.0      0.1          (energy - energy.mean(), np.diff(energy)),
#    101                                               )
#    102
#    103         1          5.0      5.0      0.0      if kind == "kde":
#    104                                                   for alpha, color, label, value in series:
#    105                                                       fill_kwargs["alpha"] = alpha
#    106                                                       fill_kwargs["color"] = color
#    107                                                       plot_kwargs.setdefault("color", color)
#    108                                                       plot_kwargs.setdefault("alpha", 0)
#    109                                                       plot_kwargs.setdefault("linewidth", linewidth)
#    110                                                       plot_kde(
#    111                                                           value,
#    112                                                           bw=bw,
#    113                                                           label=label,
#    114                                                           textsize=xt_labelsize,
#    115                                                           fill_kwargs=fill_kwargs,
#    116                                                           plot_kwargs=plot_kwargs,
#    117                                                           ax=ax,
#    118                                                           legend=False,
#    119                                                       )
#    120         1          5.0      5.0      0.0      elif kind == "hist":
#    121         3         21.0      7.0      0.0          for alpha, color, label, value in series:
#    122         2         16.0      8.0      0.0              ax.hist(
#    123         2         45.0     22.5      0.0                  value.flatten(),
#    124         2          9.0      4.5      0.0                  bins="auto",
#    125         2          9.0      4.5      0.0                  density=True,
#    126         2          9.0      4.5      0.0                  alpha=alpha,
#    127         2          9.0      4.5      0.0                  label=label,
#    128         2         12.0      6.0      0.0                  color=color,
#    129         2     305474.0 152737.0     72.4                  **plot_kwargs
#    130                                                       )
#    131
#    132                                               else:
#    133                                                   raise ValueError("Plot type {} not recognized.".format(kind))
#    134
#    135         1          4.0      4.0      0.0      if bfmi:
#    136         5        504.0    100.8      0.1          for idx, val in enumerate(e_bfmi(energy)):
#    137         4      20755.0   5188.8      4.9              ax.plot([], label="chain {:>2} BFMI = {:.2f}".format(idx, val), alpha=0)
#    138         1          2.0      2.0      0.0      if legend:
#    139         1      15544.0  15544.0      3.7          ax.legend()
#    140
#    141         1        111.0    111.0      0.0      ax.set_xticks([])
#    142         1         64.0     64.0      0.0      ax.set_yticks([])
#    143
#    144         1          1.0      1.0      0.0      return ax

# %%
lp = LineProfiler()
wrapper = lp(plot_energy)
wrapper(school, kind='hist')
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.269299 s
# File: /home/banzee/Desktop/arviz/arviz/plots/energyplot.py
# Function: plot_energy at line 10
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     10                                           def plot_energy(
#     11                                               data,
#     12                                               kind="kde",
#     13                                               bfmi=True,
#     14                                               figsize=None,
#     15                                               legend=True,
#     16                                               fill_alpha=(1, 0.75),
#     17                                               fill_color=("C0", "C5"),
#     18                                               bw=4.5,
#     19                                               textsize=None,
#     20                                               fill_kwargs=None,
#     21                                               plot_kwargs=None,
#     22                                               ax=None,
#     23                                           ):
#     24                                               """Plot energy transition distribution and marginal energy distribution in HMC algorithms.
#     25
#     26                                               This may help to diagnose poor exploration by gradient-based algorithms like HMC or NUTS.
#     27
#     28                                               Parameters
#     29                                               ----------
#     30                                               data : xarray dataset, or object that can be converted (must represent
#     31                                                      `sample_stats` and have an `energy` variable)
#     32                                               kind : str
#     33                                                   Type of plot to display (kde or histogram)
#     34                                               bfmi : bool
#     35                                                   If True add to the plot the value of the estimated Bayesian fraction of missing information
#     36                                               figsize : tuple
#     37                                                   Figure size. If None it will be defined automatically.
#     38                                               legend : bool
#     39                                                   Flag for plotting legend (defaults to True)
#     40                                               fill_alpha : tuple of floats
#     41                                                   Alpha blending value for the shaded area under the curve, between 0
#     42                                                   (no shade) and 1 (opaque). Defaults to (1, .75)
#     43                                               fill_color : tuple of valid matplotlib color
#     44                                                   Color for Marginal energy distribution and Energy transition distribution.
#     45                                                   Defaults to ('C0', 'C5')
#     46                                               bw : float
#     47                                                   Bandwidth scaling factor for the KDE. Should be larger than 0. The higher this number the
#     48                                                   smoother the KDE will be. Defaults to 4.5 which is essentially the same as the Scott's rule
#     49                                                   of thumb (the default rule used by SciPy). Only works if `kind='kde'`
#     50                                               textsize: float
#     51                                                   Text size scaling factor for labels, titles and lines. If None it will be autoscaled based
#     52                                                   on figsize.
#     53                                               fill_kwargs : dicts, optional
#     54                                                   Additional keywords passed to `arviz.plot_kde` (to control the shade)
#     55                                               plot_kwargs : dicts, optional
#     56                                                   Additional keywords passed to `arviz.plot_kde` or `plt.hist` (if type='hist')
#     57                                               ax : axes
#     58                                                   Matplotlib axes.
#     59
#     60                                               Returns
#     61                                               -------
#     62                                               ax : matplotlib axes
#     63
#     64                                               Examples
#     65                                               --------
#     66                                               Plot a default energy plot
#     67
#     68                                               .. plot::
#     69                                                   :context: close-figs
#     70
#     71                                                   >>> import arviz as az
#     72                                                   >>> data = az.load_arviz_data('centered_eight')
#     73                                                   >>> az.plot_energy(data)
#     74
#     75                                               Represent energy plot via histograms
#     76
#     77                                               .. plot::
#     78                                                   :context: close-figs
#     79
#     80                                                   >>> az.plot_energy(data, kind='hist')
#     81
#     82                                               """
#     83         1       1230.0   1230.0      0.5      energy = convert_to_dataset(data, group="sample_stats").energy.values
#     84
#     85         1          5.0      5.0      0.0      if ax is None:
#     86         1      55297.0  55297.0     20.5          _, ax = plt.subplots(figsize=figsize, constrained_layout=True)
#     87
#     88         1          4.0      4.0      0.0      if fill_kwargs is None:
#     89         1          3.0      3.0      0.0          fill_kwargs = {}
#     90
#     91         1          2.0      2.0      0.0      if plot_kwargs is None:
#     92         1          2.0      2.0      0.0          plot_kwargs = {}
#     93
#     94         1         63.0     63.0      0.0      figsize, _, _, xt_labelsize, linewidth, _ = _scale_fig_size(figsize, textsize, 1, 1)
#     95
#     96         1          3.0      3.0      0.0      series = zip(
#     97         1          2.0      2.0      0.0          fill_alpha,
#     98         1          4.0      4.0      0.0          fill_color,
#     99         1          2.0      2.0      0.0          ("Marginal Energy", "Energy transition"),
#    100         1        178.0    178.0      0.1          (energy - energy.mean(), np.diff(energy)),
#    101                                               )
#    102
#    103         1          3.0      3.0      0.0      if kind == "kde":
#    104                                                   for alpha, color, label, value in series:
#    105                                                       fill_kwargs["alpha"] = alpha
#    106                                                       fill_kwargs["color"] = color
#    107                                                       plot_kwargs.setdefault("color", color)
#    108                                                       plot_kwargs.setdefault("alpha", 0)
#    109                                                       plot_kwargs.setdefault("linewidth", linewidth)
#    110                                                       plot_kde(
#    111                                                           value,
#    112                                                           bw=bw,
#    113                                                           label=label,
#    114                                                           textsize=xt_labelsize,
#    115                                                           fill_kwargs=fill_kwargs,
#    116                                                           plot_kwargs=plot_kwargs,
#    117                                                           ax=ax,
#    118                                                           legend=False,
#    119                                                       )
#    120         1          2.0      2.0      0.0      elif kind == "hist":
#    121         3         14.0      4.7      0.0          for alpha, color, label, value in series:
#    122         2          9.0      4.5      0.0              ax.hist(
#    123         2         28.0     14.0      0.0                  value.flatten(),
#    124         2          4.0      2.0      0.0                  bins="auto",
#    125         2          4.0      2.0      0.0                  density=True,
#    126         2          3.0      1.5      0.0                  alpha=alpha,
#    127         2          4.0      2.0      0.0                  label=label,
#    128         2          5.0      2.5      0.0                  color=color,
#    129         2     176501.0  88250.5     65.5                  **plot_kwargs
#    130                                                       )
#    131
#    132                                               else:
#    133                                                   raise ValueError("Plot type {} not recognized.".format(kind))
#    134
#    135         1          2.0      2.0      0.0      if bfmi:
#    136         5        510.0    102.0      0.2          for idx, val in enumerate(e_bfmi(energy)):
#    137         4      19517.0   4879.2      7.2              ax.plot([], label="chain {:>2} BFMI = {:.2f}".format(idx, val), alpha=0)
#    138         1          3.0      3.0      0.0      if legend:
#    139         1      15711.0  15711.0      5.8          ax.legend()
#    140
#    141         1        115.0    115.0      0.0      ax.set_xticks([])
#    142         1         67.0     67.0      0.0      ax.set_yticks([])
#    143
#    144         1          2.0      2.0      0.0      return ax

# %%
## bottlenecks plot_kde, hist and bfmi

# %%
"""""""""""""""""""""""""""""""""""""""""PLOT_KDE"""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""""
# Out:
# '""PLOT_KDE'

# %%
"""One-dimensional kernel density estimate plots."""
import warnings
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import gaussian, convolve, convolve2d  # pylint: disable=no-name-in-module
from scipy.sparse import coo_matrix
import xarray as xr
from arviz.data import InferenceData
from arviz.plots.plot_utils import _scale_fig_size
from arviz.utils import conditional_jit


def plot_kde(
    values,
    values2=None,
    cumulative=False,
    rug=False,
    label=None,
    bw=4.5,
    quantiles=None,
    rotated=False,
    contour=True,
    fill_last=True,
    textsize=None,
    plot_kwargs=None,
    fill_kwargs=None,
    rug_kwargs=None,
    contour_kwargs=None,
    contourf_kwargs=None,
    pcolormesh_kwargs=None,
    ax=None,
    legend=True,
):

    if ax is None:
        ax = plt.gca()

    figsize = ax.get_figure().get_size_inches()

    figsize, *_, xt_labelsize, linewidth, markersize = _scale_fig_size(figsize, textsize, 1, 1)

    if isinstance(values, xr.Dataset):
        raise ValueError(
            "Xarray dataset object detected.Use plot_posterior, plot_density, plot_joint"
            "or plot_pair instead of plot_kde"
        )
    if isinstance(values, InferenceData):
        raise ValueError(" Inference Data object detected. Use plot_posterior instead of plot_kde")

    if values2 is None:
        if plot_kwargs is None:
            plot_kwargs = {}
        plot_kwargs.setdefault("color", "C0")

        default_color = plot_kwargs.get("color")

        if fill_kwargs is None:
            fill_kwargs = {}

        fill_kwargs.setdefault("color", default_color)

        if rug_kwargs is None:
            rug_kwargs = {}
        rug_kwargs.setdefault("marker", "_" if rotated else "|")
        rug_kwargs.setdefault("linestyle", "None")
        rug_kwargs.setdefault("color", default_color)
        rug_kwargs.setdefault("space", 0.2)

        plot_kwargs.setdefault("linewidth", linewidth)
        rug_kwargs.setdefault("markersize", 2 * markersize)

        density, lower, upper = _fast_kde(values, cumulative, bw)

        rug_space = max(density) * rug_kwargs.pop("space")

        x = np.linspace(lower, upper, len(density))

        if cumulative:
            density_q = density
        else:
            density_q = density.cumsum() / density.sum()
        fill_func = ax.fill_between
        fill_x, fill_y = x, density
        if rotated:
            x, density = density, x
            fill_func = ax.fill_betweenx

        ax.tick_params(labelsize=xt_labelsize)

        if rotated:
            ax.set_xlim(0, auto=True)
            rug_x, rug_y = np.zeros_like(values) - rug_space, values
        else:
            ax.set_ylim(0, auto=True)
            rug_x, rug_y = values, np.zeros_like(values) - rug_space

        if rug:
            ax.plot(rug_x, rug_y, **rug_kwargs)

        if quantiles is not None:
            fill_kwargs.setdefault("alpha", 0.75)

            idx = [np.sum(density_q < quant) for quant in quantiles]

            fill_func(
                fill_x,
                fill_y,
                where=np.isin(fill_x, fill_x[idx], invert=True, assume_unique=True),
                **fill_kwargs
            )
        else:
            fill_kwargs.setdefault("alpha", 0)
            if fill_kwargs.get("alpha") == 0:
                ax.plot(x, density, label=label, **plot_kwargs)
                fill_func(fill_x, fill_y, **fill_kwargs)
            else:
                ax.plot(x, density, **plot_kwargs)
                fill_func(fill_x, fill_y, label=label, **fill_kwargs)
        if legend and label:
            ax.legend()
    else:
        if contour_kwargs is None:
            contour_kwargs = {}
        contour_kwargs.setdefault("colors", "0.5")
        if contourf_kwargs is None:
            contourf_kwargs = {}
        if pcolormesh_kwargs is None:
            pcolormesh_kwargs = {}

        gridsize = (128, 128) if contour else (256, 256)

        density, xmin, xmax, ymin, ymax = _fast_kde_2d(values, values2, gridsize=gridsize)
        g_s = complex(gridsize[0])
        x_x, y_y = np.mgrid[xmin:xmax:g_s, ymin:ymax:g_s]

        ax.grid(False)
        ax.set_xlim(xmin, xmax)
        ax.set_ylim(ymin, ymax)
        if contour:
            qcfs = ax.contourf(x_x, y_y, density, antialiased=True, **contourf_kwargs)
            qcs = ax.contour(x_x, y_y, density, **contour_kwargs)
            if not fill_last:
                qcfs.collections[0].set_alpha(0)
                qcs.collections[0].set_alpha(0)
        else:
            ax.pcolormesh(x_x, y_y, density, **pcolormesh_kwargs)

    return ax


def _fast_kde(x, cumulative=False, bw=4.5, xmin=None, xmax=None):
    x = np.asarray(x, dtype=float)
    x = x[np.isfinite(x)]
    if x.size == 0:
        warnings.warn("kde plot failed, you may want to check your data")
        return np.array([np.nan]), np.nan, np.nan

    len_x = len(x)
    n_points = 200 if (xmin or xmax) is None else 500

    if xmin is None:
        xmin = np.min(x)
    if xmax is None:
        xmax = np.max(x)

    assert np.min(x) >= xmin
    assert np.max(x) <= xmax

    log_len_x = np.log(len_x) * bw

    n_bins = min(int(len_x ** (1 / 3) * log_len_x * 2), n_points)
    if n_bins < 2:
        warnings.warn("kde plot failed, you may want to check your data")
        return np.array([np.nan]), np.nan, np.nan

    d_x = (xmax - xmin) / (n_bins - 1)
    grid = _histogram(x, n_bins, range_hist=(xmin, xmax))

    scotts_factor = len_x ** (-0.2)
    kern_nx = int(scotts_factor * 2 * np.pi * log_len_x)
    kernel = gaussian(kern_nx, scotts_factor * log_len_x)

    npad = min(n_bins, 2 * kern_nx)
    grid = np.concatenate([grid[npad:0:-1], grid, grid[n_bins : n_bins - npad : -1]])
    density = convolve(grid, kernel, mode="same", method="direct")[npad : npad + n_bins]
    norm_factor = len_x * d_x * (2 * np.pi * log_len_x ** 2 * scotts_factor ** 2) ** 0.5

    density /= norm_factor

    if cumulative:
        density = density.cumsum() / density.sum()

    return density, xmin, xmax


def _histogram(x, n_bins, range_hist=None):
    grid, _ = np.histogram(x, bins=n_bins, range=range_hist)
    return grid


def _fast_kde_2d(x, y, gridsize=(128, 128), circular=False):
    x = np.asarray(x, dtype=float)
    x = x[np.isfinite(x)]
    y = np.asarray(y, dtype=float)
    y = y[np.isfinite(y)]

    xmin, xmax = x.min(), x.max()
    ymin, ymax = y.min(), y.max()

    len_x = len(x)
    weights = np.ones(len_x)
    n_x, n_y = gridsize

    d_x = (xmax - xmin) / (n_x - 1)
    d_y = (ymax - ymin) / (n_y - 1)

    xyi = np.vstack((x, y)).T
    xyi -= [xmin, ymin]
    xyi /= [d_x, d_y]
    xyi = np.floor(xyi, xyi).T

    scotts_factor = len_x ** (-1 / 6)
    cov = np.cov(xyi)
    std_devs = np.diag(cov ** 0.5)
    kern_nx, kern_ny = np.round(scotts_factor * 2 * np.pi * std_devs)

    inv_cov = np.linalg.inv(cov * scotts_factor ** 2)

    x_x = np.arange(kern_nx) - kern_nx / 2
    y_y = np.arange(kern_ny) - kern_ny / 2
    x_x, y_y = np.meshgrid(x_x, y_y)

    kernel = np.vstack((x_x.flatten(), y_y.flatten()))
    kernel = np.dot(inv_cov, kernel) * kernel
    kernel = np.exp(-kernel.sum(axis=0) / 2)
    kernel = kernel.reshape((int(kern_ny), int(kern_nx)))

    boundary = "wrap" if circular else "symm"

    grid = coo_matrix((weights, xyi), shape=(n_x, n_y)).toarray()
    grid = convolve2d(grid, kernel, mode="same", boundary=boundary)

    norm_factor = np.linalg.det(2 * np.pi * cov * scotts_factor ** 2)
    norm_factor = len_x * d_x * d_y * norm_factor ** 0.5

    grid /= norm_factor

    return grid, xmin, xmax, ymin, ymax

# %%
data = np.random.randn(1000, 1000)

# %%
# %timeit plot_kde(data)
# Out:
# 20.3 ms ± 1.69 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
lp = LineProfiler()
wrapper = lp(plot_kde)
wrapper(data)
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.103441 s
# File: <ipython-input-37-3d462aa102ef>
# Function: plot_kde at line 13
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     13                                           def plot_kde(
#     14                                               values,
#     15                                               values2=None,
#     16                                               cumulative=False,
#     17                                               rug=False,
#     18                                               label=None,
#     19                                               bw=4.5,
#     20                                               quantiles=None,
#     21                                               rotated=False,
#     22                                               contour=True,
#     23                                               fill_last=True,
#     24                                               textsize=None,
#     25                                               plot_kwargs=None,
#     26                                               fill_kwargs=None,
#     27                                               rug_kwargs=None,
#     28                                               contour_kwargs=None,
#     29                                               contourf_kwargs=None,
#     30                                               pcolormesh_kwargs=None,
#     31                                               ax=None,
#     32                                               legend=True,
#     33                                           ):
#     34
#     35         1          7.0      7.0      0.0      if ax is None:
#     36         1      52836.0  52836.0     51.1          ax = plt.gca()
#     37
#     38         1         32.0     32.0      0.0      figsize = ax.get_figure().get_size_inches()
#     39
#     40         1        148.0    148.0      0.1      figsize, *_, xt_labelsize, linewidth, markersize = _scale_fig_size(figsize, textsize, 1, 1)
#     41
#     42         1         41.0     41.0      0.0      if isinstance(values, xr.Dataset):
#     43                                                   raise ValueError(
#     44                                                       "Xarray dataset object detected.Use plot_posterior, plot_density, plot_joint"
#     45                                                       "or plot_pair instead of plot_kde"
#     46                                                   )
#     47         1          8.0      8.0      0.0      if isinstance(values, InferenceData):
#     48                                                   raise ValueError(" Inference Data object detected. Use plot_posterior instead of plot_kde")
#     49
#     50         1          7.0      7.0      0.0      if values2 is None:
#     51         1          8.0      8.0      0.0          if plot_kwargs is None:
#     52         1          7.0      7.0      0.0              plot_kwargs = {}
#     53         1          9.0      9.0      0.0          plot_kwargs.setdefault("color", "C0")
#     54
#     55         1          8.0      8.0      0.0          default_color = plot_kwargs.get("color")
#     56
#     57         1          7.0      7.0      0.0          if fill_kwargs is None:
#     58         1          6.0      6.0      0.0              fill_kwargs = {}
#     59
#     60         1          8.0      8.0      0.0          fill_kwargs.setdefault("color", default_color)
#     61
#     62         1          7.0      7.0      0.0          if rug_kwargs is None:
#     63         1          7.0      7.0      0.0              rug_kwargs = {}
#     64         1          7.0      7.0      0.0          rug_kwargs.setdefault("marker", "_" if rotated else "|")
#     65         1          8.0      8.0      0.0          rug_kwargs.setdefault("linestyle", "None")
#     66         1          8.0      8.0      0.0          rug_kwargs.setdefault("color", default_color)
#     67         1          7.0      7.0      0.0          rug_kwargs.setdefault("space", 0.2)
#     68
#     69         1          8.0      8.0      0.0          plot_kwargs.setdefault("linewidth", linewidth)
#     70         1          9.0      9.0      0.0          rug_kwargs.setdefault("markersize", 2 * markersize)
#     71
#     72         1      36996.0  36996.0     35.8          density, lower, upper = _fast_kde(values, cumulative, bw)
#     73
#     74         1         35.0     35.0      0.0          rug_space = max(density) * rug_kwargs.pop("space")
#     75
#     76         1         76.0     76.0      0.1          x = np.linspace(lower, upper, len(density))
#     77
#     78         1          3.0      3.0      0.0          if cumulative:
#     79                                                       density_q = density
#     80                                                   else:
#     81         1         34.0     34.0      0.0              density_q = density.cumsum() / density.sum()
#     82         1          6.0      6.0      0.0          fill_func = ax.fill_between
#     83         1          3.0      3.0      0.0          fill_x, fill_y = x, density
#     84         1          2.0      2.0      0.0          if rotated:
#     85                                                       x, density = density, x
#     86                                                       fill_func = ax.fill_betweenx
#     87
#     88         1        732.0    732.0      0.7          ax.tick_params(labelsize=xt_labelsize)
#     89
#     90         1          4.0      4.0      0.0          if rotated:
#     91                                                       ax.set_xlim(0, auto=True)
#     92                                                       rug_x, rug_y = np.zeros_like(values) - rug_space, values
#     93                                                   else:
#     94         1        185.0    185.0      0.2              ax.set_ylim(0, auto=True)
#     95         1       4874.0   4874.0      4.7              rug_x, rug_y = values, np.zeros_like(values) - rug_space
#     96
#     97         1          5.0      5.0      0.0          if rug:
#     98                                                       ax.plot(rug_x, rug_y, **rug_kwargs)
#     99
#    100         1          3.0      3.0      0.0          if quantiles is not None:
#    101                                                       fill_kwargs.setdefault("alpha", 0.75)
#    102
#    103                                                       idx = [np.sum(density_q < quant) for quant in quantiles]
#    104
#    105                                                       fill_func(
#    106                                                           fill_x,
#    107                                                           fill_y,
#    108                                                           where=np.isin(fill_x, fill_x[idx], invert=True, assume_unique=True),
#    109                                                           **fill_kwargs
#    110                                                       )
#    111                                                   else:
#    112         1          6.0      6.0      0.0              fill_kwargs.setdefault("alpha", 0)
#    113         1          4.0      4.0      0.0              if fill_kwargs.get("alpha") == 0:
#    114         1       3539.0   3539.0      3.4                  ax.plot(x, density, label=label, **plot_kwargs)
#    115         1       3735.0   3735.0      3.6                  fill_func(fill_x, fill_y, **fill_kwargs)
#    116                                                       else:
#    117                                                           ax.plot(x, density, **plot_kwargs)
#    118                                                           fill_func(fill_x, fill_y, label=label, **fill_kwargs)
#    119         1          4.0      4.0      0.0          if legend and label:
#    120                                                       ax.legend()
#    121                                               else:
#    122                                                   if contour_kwargs is None:
#    123                                                       contour_kwargs = {}
#    124                                                   contour_kwargs.setdefault("colors", "0.5")
#    125                                                   if contourf_kwargs is None:
#    126                                                       contourf_kwargs = {}
#    127                                                   if pcolormesh_kwargs is None:
#    128                                                       pcolormesh_kwargs = {}
#    129
#    130                                                   gridsize = (128, 128) if contour else (256, 256)
#    131
#    132                                                   density, xmin, xmax, ymin, ymax = _fast_kde_2d(values, values2, gridsize=gridsize)
#    133                                                   g_s = complex(gridsize[0])
#    134                                                   x_x, y_y = np.mgrid[xmin:xmax:g_s, ymin:ymax:g_s]
#    135
#    136                                                   ax.grid(False)
#    137                                                   ax.set_xlim(xmin, xmax)
#    138                                                   ax.set_ylim(ymin, ymax)
#    139                                                   if contour:
#    140                                                       qcfs = ax.contourf(x_x, y_y, density, antialiased=True, **contourf_kwargs)
#    141                                                       qcs = ax.contour(x_x, y_y, density, **contour_kwargs)
#    142                                                       if not fill_last:
#    143                                                           qcfs.collections[0].set_alpha(0)
#    144                                                           qcs.collections[0].set_alpha(0)
#    145                                                   else:
#    146                                                       ax.pcolormesh(x_x, y_y, density, **pcolormesh_kwargs)
#    147
#    148         1          2.0      2.0      0.0      return ax

# %%
#fast_kde is the bottleneck

# %%
def _fast_kde(x, cumulative=False, bw=4.5, xmin=None, xmax=None):
    x = np.asarray(x, dtype=float)
    x = x[np.isfinite(x)]
    if x.size == 0:
        warnings.warn("kde plot failed, you may want to check your data")
        return np.array([np.nan]), np.nan, np.nan

    len_x = len(x)
    n_points = 200 if (xmin or xmax) is None else 500

    if xmin is None:
        xmin = np.min(x)
    if xmax is None:
        xmax = np.max(x)

    assert np.min(x) >= xmin
    assert np.max(x) <= xmax

    log_len_x = np.log(len_x) * bw

    n_bins = min(int(len_x ** (1 / 3) * log_len_x * 2), n_points)
    if n_bins < 2:
        warnings.warn("kde plot failed, you may want to check your data")
        return np.array([np.nan]), np.nan, np.nan

    d_x = (xmax - xmin) / (n_bins - 1)
    grid = _histogram(x, n_bins, range_hist=(xmin, xmax))

    scotts_factor = len_x ** (-0.2)
    kern_nx = int(scotts_factor * 2 * np.pi * log_len_x)
    kernel = gaussian(kern_nx, scotts_factor * log_len_x)

    npad = min(n_bins, 2 * kern_nx)
    grid = np.concatenate([grid[npad:0:-1], grid, grid[n_bins : n_bins - npad : -1]])
    density = convolve(grid, kernel, mode="same", method="direct")[npad : npad + n_bins]
    norm_factor = len_x * d_x * (2 * np.pi * log_len_x ** 2 * scotts_factor ** 2) ** 0.5

    density /= norm_factor

    if cumulative:
        density = density.cumsum() / density.sum()

    return density, xmin, xmax


def _histogram(x, n_bins, range_hist=None):
    grid, _ = np.histogram(x, bins=n_bins, range=range_hist)
    return grid

# %%
lp = LineProfiler()
wrapper = lp(_fast_kde)
wrapper(data)
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.045273 s
# File: <ipython-input-42-673acd49bfaa>
# Function: _fast_kde at line 2
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      2                                           def _fast_kde(x, cumulative=False, bw=4.5, xmin=None, xmax=None):
#      3         1         14.0     14.0      0.0      x = np.asarray(x, dtype=float)
#      4         1       5558.0   5558.0     12.3      x = x[np.isfinite(x)]
#      5         1          9.0      9.0      0.0      if x.size == 0:
#      6                                                   warnings.warn("kde plot failed, you may want to check your data")
#      7                                                   return np.array([np.nan]), np.nan, np.nan
#      8
#      9         1          5.0      5.0      0.0      len_x = len(x)
#     10         1          4.0      4.0      0.0      n_points = 200 if (xmin or xmax) is None else 500
#     11
#     12         1          3.0      3.0      0.0      if xmin is None:
#     13         1       1223.0   1223.0      2.7          xmin = np.min(x)
#     14         1          3.0      3.0      0.0      if xmax is None:
#     15         1       1151.0   1151.0      2.5          xmax = np.max(x)
#     16
#     17         1       1231.0   1231.0      2.7      assert np.min(x) >= xmin
#     18         1       1440.0   1440.0      3.2      assert np.max(x) <= xmax
#     19
#     20         1         35.0     35.0      0.1      log_len_x = np.log(len_x) * bw
#     21
#     22         1         17.0     17.0      0.0      n_bins = min(int(len_x ** (1 / 3) * log_len_x * 2), n_points)
#     23         1          3.0      3.0      0.0      if n_bins < 2:
#     24                                                   warnings.warn("kde plot failed, you may want to check your data")
#     25                                                   return np.array([np.nan]), np.nan, np.nan
#     26
#     27         1          5.0      5.0      0.0      d_x = (xmax - xmin) / (n_bins - 1)
#     28         1      34329.0  34329.0     75.8      grid = _histogram(x, n_bins, range_hist=(xmin, xmax))
#     29
#     30         1         11.0     11.0      0.0      scotts_factor = len_x ** (-0.2)
#     31         1         13.0     13.0      0.0      kern_nx = int(scotts_factor * 2 * np.pi * log_len_x)
#     32         1        108.0    108.0      0.2      kernel = gaussian(kern_nx, scotts_factor * log_len_x)
#     33
#     34         1          4.0      4.0      0.0      npad = min(n_bins, 2 * kern_nx)
#     35         1         17.0     17.0      0.0      grid = np.concatenate([grid[npad:0:-1], grid, grid[n_bins : n_bins - npad : -1]])
#     36         1         66.0     66.0      0.1      density = convolve(grid, kernel, mode="same", method="direct")[npad : npad + n_bins]
#     37         1          8.0      8.0      0.0      norm_factor = len_x * d_x * (2 * np.pi * log_len_x ** 2 * scotts_factor ** 2) ** 0.5
#     38
#     39         1         12.0     12.0      0.0      density /= norm_factor
#     40
#     41         1          2.0      2.0      0.0      if cumulative:
#     42                                                   density = density.cumsum() / density.sum()
#     43
#     44         1          2.0      2.0      0.0      return density, xmin, xmax

# %%
lp = LineProfiler()
wrapper = lp(_fast_kde)
wrapper(load_arviz_data("centered_eight").posterior["mu"].values)
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.000679 s
# File: <ipython-input-49-d945a1adbb85>
# Function: _fast_kde at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def _fast_kde(x, cumulative=False, bw=4.5, xmin=None, xmax=None):
#      2         1         10.0     10.0      1.5      x = np.asarray(x, dtype=float)
#      3         1         25.0     25.0      3.7      x = x[np.isfinite(x)]
#      4         1          3.0      3.0      0.4      if x.size == 0:
#      5                                                   warnings.warn("kde plot failed, you may want to check your data")
#      6                                                   return np.array([np.nan]), np.nan, np.nan
#      7
#      8         1          2.0      2.0      0.3      len_x = len(x)
#      9         1          2.0      2.0      0.3      n_points = 200 if (xmin or xmax) is None else 500
#     10
#     11         1          1.0      1.0      0.1      if xmin is None:
#     12         1         28.0     28.0      4.1          xmin = np.min(x)
#     13         1          2.0      2.0      0.3      if xmax is None:
#     14         1         15.0     15.0      2.2          xmax = np.max(x)
#     15
#     16         1         12.0     12.0      1.8      assert np.min(x) >= xmin
#     17         1         10.0     10.0      1.5      assert np.max(x) <= xmax
#     18
#     19         1         12.0     12.0      1.8      log_len_x = np.log(len_x) * bw
#     20
#     21         1         10.0     10.0      1.5      n_bins = min(int(len_x ** (1 / 3) * log_len_x * 2), n_points)
#     22         1          2.0      2.0      0.3      if n_bins < 2:
#     23                                                   warnings.warn("kde plot failed, you may want to check your data")
#     24                                                   return np.array([np.nan]), np.nan, np.nan
#     25
#     26         1          4.0      4.0      0.6      d_x = (xmax - xmin) / (n_bins - 1)
#     27         1        386.0    386.0     56.8      grid = _histogram(x, n_bins, range_hist=(xmin, xmax))
#     28
#     29         1          4.0      4.0      0.6      scotts_factor = len_x ** (-0.2)
#     30         1          5.0      5.0      0.7      kern_nx = int(scotts_factor * 2 * np.pi * log_len_x)
#     31         1         44.0     44.0      6.5      kernel = gaussian(kern_nx, scotts_factor * log_len_x)
#     32
#     33         1          4.0      4.0      0.6      npad = min(n_bins, 2 * kern_nx)
#     34         1         13.0     13.0      1.9      grid = np.concatenate([grid[npad:0:-1], grid, grid[n_bins : n_bins - npad : -1]])
#     35         1         66.0     66.0      9.7      density = convolve(grid, kernel, mode="same", method="direct")[npad : npad + n_bins]
#     36         1          7.0      7.0      1.0      norm_factor = len_x * d_x * (2 * np.pi * log_len_x ** 2 * scotts_factor ** 2) ** 0.5
#     37
#     38         1          9.0      9.0      1.3      density /= norm_factor
#     39
#     40         1          2.0      2.0      0.3      if cumulative:
#     41                                                   density = density.cumsum() / density.sum()
#     42
#     43         1          1.0      1.0      0.1      return density, xmin, xmax

# %%
# histogram is the bottleneck!! Yes!

# %%
school = load_arviz_data("centered_eight").posterior["mu"].values
n_school = load_arviz_data("non_centered_eight").posterior["mu"].values

# %%
def _fast_kde(x, cumulative=False, bw=4.5, xmin=None, xmax=None):
    x = np.asarray(x, dtype=float)
    x = x[np.isfinite(x)]
    if x.size == 0:
        warnings.warn("kde plot failed, you may want to check your data")
        return np.array([np.nan]), np.nan, np.nan

    len_x = len(x)
    n_points = 200 if (xmin or xmax) is None else 500

    if xmin is None:
        xmin = np.min(x)
    if xmax is None:
        xmax = np.max(x)

    assert np.min(x) >= xmin
    assert np.max(x) <= xmax

    log_len_x = np.log(len_x) * bw

    n_bins = min(int(len_x ** (1 / 3) * log_len_x * 2), n_points)
    if n_bins < 2:
        warnings.warn("kde plot failed, you may want to check your data")
        return np.array([np.nan]), np.nan, np.nan

    d_x = (xmax - xmin) / (n_bins - 1)
    grid = _histogram(x, n_bins, range_hist=(xmin, xmax))

    scotts_factor = len_x ** (-0.2)
    kern_nx = int(scotts_factor * 2 * np.pi * log_len_x)
    kernel = gaussian(kern_nx, scotts_factor * log_len_x)

    npad = min(n_bins, 2 * kern_nx)
    grid = np.concatenate([grid[npad:0:-1], grid, grid[n_bins : n_bins - npad : -1]])
    density = convolve(grid, kernel, mode="same", method="direct")[npad : npad + n_bins]
    norm_factor = len_x * d_x * (2 * np.pi * log_len_x ** 2 * scotts_factor ** 2) ** 0.5

    density /= norm_factor

    if cumulative:
        density = density.cumsum() / density.sum()

    return density, xmin, xmax


def _histogram(x, n_bins, range_hist=None):
    grid, _ = np.histogram(x, bins=n_bins, range=range_hist)
    return grid



def _fast_kde_jit(x, cumulative=False, bw=4.5, xmin=None, xmax=None):
    x = np.asarray(x, dtype=float)
    x = x[np.isfinite(x)]
    if x.size == 0:
        warnings.warn("kde plot failed, you may want to check your data")
        return np.array([np.nan]), np.nan, np.nan

    len_x = len(x)
    n_points = 200 if (xmin or xmax) is None else 500

    if xmin is None:
        xmin = np.min(x)
    if xmax is None:
        xmax = np.max(x)

    assert np.min(x) >= xmin
    assert np.max(x) <= xmax

    log_len_x = np.log(len_x) * bw

    n_bins = min(int(len_x ** (1 / 3) * log_len_x * 2), n_points)
    if n_bins < 2:
        warnings.warn("kde plot failed, you may want to check your data")
        return np.array([np.nan]), np.nan, np.nan

    d_x = (xmax - xmin) / (n_bins - 1)
    grid = _histogram_jit(x, n_bins, range_hist=(xmin, xmax))

    scotts_factor = len_x ** (-0.2)
    kern_nx = int(scotts_factor * 2 * np.pi * log_len_x)
    kernel = gaussian(kern_nx, scotts_factor * log_len_x)

    npad = min(n_bins, 2 * kern_nx)
    grid = np.concatenate([grid[npad:0:-1], grid, grid[n_bins : n_bins - npad : -1]])
    density = convolve(grid, kernel, mode="same", method="direct")[npad : npad + n_bins]
    norm_factor = len_x * d_x * (2 * np.pi * log_len_x ** 2 * scotts_factor ** 2) ** 0.5

    density /= norm_factor

    if cumulative:
        density = density.cumsum() / density.sum()

    return density, xmin, xmax

@conditional_jit
def _histogram_jit(x, n_bins, range_hist=None):
    grid, _ = np.histogram(x, bins=n_bins, range=range_hist)
    return grid

# %%
# %timeit _fast_kde(data)
# Out:
# 28.3 ms ± 1.14 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit _fast_kde_jit(data)
# Out:
# 10.4 ms ± 172 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit _fast_kde(school)
# Out:
# 374 µs ± 41.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit _fast_kde_jit(school)
# Out:
# 163 µs ± 24.3 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# Much faster

# %%
def _fast_kde_2d(x, y, gridsize=(128, 128), circular=False):
    x = np.asarray(x, dtype=float)
    x = x[np.isfinite(x)]
    y = np.asarray(y, dtype=float)
    y = y[np.isfinite(y)]

    xmin, xmax = x.min(), x.max()
    ymin, ymax = y.min(), y.max()

    len_x = len(x)
    weights = np.ones(len_x)
    n_x, n_y = gridsize

    d_x = (xmax - xmin) / (n_x - 1)
    d_y = (ymax - ymin) / (n_y - 1)

    xyi = np.vstack((x, y)).T
    xyi -= [xmin, ymin]
    xyi /= [d_x, d_y]
    xyi = np.floor(xyi, xyi).T

    scotts_factor = len_x ** (-1 / 6)
    cov = np.cov(xyi)
    std_devs = np.diag(cov ** 0.5)
    kern_nx, kern_ny = np.round(scotts_factor * 2 * np.pi * std_devs)

    inv_cov = np.linalg.inv(cov * scotts_factor ** 2)

    x_x = np.arange(kern_nx) - kern_nx / 2
    y_y = np.arange(kern_ny) - kern_ny / 2
    x_x, y_y = np.meshgrid(x_x, y_y)

    kernel = np.vstack((x_x.flatten(), y_y.flatten()))
    kernel = np.dot(inv_cov, kernel) * kernel
    kernel = np.exp(-kernel.sum(axis=0) / 2)
    kernel = kernel.reshape((int(kern_ny), int(kern_nx)))

    boundary = "wrap" if circular else "symm"

    grid = coo_matrix((weights, xyi), shape=(n_x, n_y)).toarray()
    grid = convolve2d(grid, kernel, mode="same", boundary=boundary)

    norm_factor = np.linalg.det(2 * np.pi * cov * scotts_factor ** 2)
    norm_factor = len_x * d_x * d_y * norm_factor ** 0.5

    grid /= norm_factor

    return grid, xmin, xmax, ymin, ymax


import numba
@numba.jit
def _fast_kde_2d_jit(x, y, gridsize=(128, 128), circular=False):
    x = np.asarray(x, dtype=float)
    x = x[np.isfinite(x)]
    y = np.asarray(y, dtype=float)
    y = y[np.isfinite(y)]

    xmin, xmax = x.min(), x.max()
    ymin, ymax = y.min(), y.max()

    len_x = len(x)
    weights = np.ones(len_x)
    n_x, n_y = gridsize

    d_x = (xmax - xmin) / (n_x - 1)
    d_y = (ymax - ymin) / (n_y - 1)

    xyi = np.vstack((x, y)).T
    xyi -= [xmin, ymin]
    xyi /= [d_x, d_y]
    xyi = np.floor(xyi, xyi).T

    scotts_factor = len_x ** (-1 / 6)
    cov = np.cov(xyi)
    std_devs = np.diag(cov ** 0.5)
    kern_nx, kern_ny = np.round(scotts_factor * 2 * np.pi * std_devs)

    inv_cov = np.linalg.inv(cov * scotts_factor ** 2)

    x_x = np.arange(kern_nx) - kern_nx / 2
    y_y = np.arange(kern_ny) - kern_ny / 2
    x_x, y_y = np.meshgrid(x_x, y_y)

    kernel = np.vstack((x_x.flatten(), y_y.flatten()))
    kernel = np.dot(inv_cov, kernel) * kernel
    kernel = np.exp(-kernel.sum(axis=0) / 2)
    kernel = kernel.reshape((int(kern_ny), int(kern_nx)))

    boundary = "wrap" if circular else "symm"

    grid = coo_matrix((weights, xyi), shape=(n_x, n_y)).toarray()
    grid = convolve2d(grid, kernel, mode="same", boundary=boundary)

    norm_factor = np.linalg.det(2 * np.pi * cov * scotts_factor ** 2)
    norm_factor = len_x * d_x * d_y * norm_factor ** 0.5

    grid /= norm_factor

    return grid, xmin, xmax, ymin, ymax

# %%
# %timeit _fast_kde_2d(data, np.random.randn(1000, 1000))
# Out:
# /home/banzee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in sqrt
# 146 ms ± 9.13 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit _fast_kde_2d_jit(data, np.random.randn(1000, 1000))
# Out:
# /home/banzee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sqrt
#   """Entry point for launching an IPython kernel.
# 150 ms ± 19.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
lp = LineProfiler()
wrapper = lp(_fast_kde_2d)
wrapper(data, np.random.randn(1000, 1000))
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.187084 s
# File: <ipython-input-52-5d943c0e0f88>
# Function: _fast_kde_2d at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def _fast_kde_2d(x, y, gridsize=(128, 128), circular=False):
#      2         1         19.0     19.0      0.0      x = np.asarray(x, dtype=float)
#      3         1       6331.0   6331.0      3.4      x = x[np.isfinite(x)]
#      4         1         21.0     21.0      0.0      y = np.asarray(y, dtype=float)
#      5         1       6296.0   6296.0      3.4      y = y[np.isfinite(y)]
#      6
#      7         1       1917.0   1917.0      1.0      xmin, xmax = x.min(), x.max()
#      8         1       1936.0   1936.0      1.0      ymin, ymax = y.min(), y.max()
#      9
#     10         1          8.0      8.0      0.0      len_x = len(x)
#     11         1       5745.0   5745.0      3.1      weights = np.ones(len_x)
#     12         1          6.0      6.0      0.0      n_x, n_y = gridsize
#     13
#     14         1         19.0     19.0      0.0      d_x = (xmax - xmin) / (n_x - 1)
#     15         1          6.0      6.0      0.0      d_y = (ymax - ymin) / (n_y - 1)
#     16
#     17         1       8111.0   8111.0      4.3      xyi = np.vstack((x, y)).T
#     18         1       5701.0   5701.0      3.0      xyi -= [xmin, ymin]
#     19         1       7005.0   7005.0      3.7      xyi /= [d_x, d_y]
#     20         1       4180.0   4180.0      2.2      xyi = np.floor(xyi, xyi).T
#     21
#     22         1         11.0     11.0      0.0      scotts_factor = len_x ** (-1 / 6)
#     23         1      22409.0  22409.0     12.0      cov = np.cov(xyi)
#     24         1      93539.0  93539.0     50.0      std_devs = np.diag(cov ** 0.5)
#     25         1         70.0     70.0      0.0      kern_nx, kern_ny = np.round(scotts_factor * 2 * np.pi * std_devs)
#     26
#     27         1        121.0    121.0      0.1      inv_cov = np.linalg.inv(cov * scotts_factor ** 2)
#     28
#     29         1         35.0     35.0      0.0      x_x = np.arange(kern_nx) - kern_nx / 2
#     30         1         20.0     20.0      0.0      y_y = np.arange(kern_ny) - kern_ny / 2
#     31         1        267.0    267.0      0.1      x_x, y_y = np.meshgrid(x_x, y_y)
#     32
#     33         1        310.0    310.0      0.2      kernel = np.vstack((x_x.flatten(), y_y.flatten()))
#     34         1         63.0     63.0      0.0      kernel = np.dot(inv_cov, kernel) * kernel
#     35         1         56.0     56.0      0.0      kernel = np.exp(-kernel.sum(axis=0) / 2)
#     36         1          9.0      9.0      0.0      kernel = kernel.reshape((int(kern_ny), int(kern_nx)))
#     37
#     38         1          3.0      3.0      0.0      boundary = "wrap" if circular else "symm"
#     39
#     40         1      13539.0  13539.0      7.2      grid = coo_matrix((weights, xyi), shape=(n_x, n_y)).toarray()
#     41         1       9150.0   9150.0      4.9      grid = convolve2d(grid, kernel, mode="same", boundary=boundary)
#     42
#     43         1        114.0    114.0      0.1      norm_factor = np.linalg.det(2 * np.pi * cov * scotts_factor ** 2)
#     44         1          7.0      7.0      0.0      norm_factor = len_x * d_x * d_y * norm_factor ** 0.5
#     45
#     46         1         58.0     58.0      0.0      grid /= norm_factor
#     47
#     48         1          2.0      2.0      0.0      return grid, xmin, xmax, ymin, ymax
# /home/banzee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in sqrt

# %%
lp = LineProfiler()
wrapper = lp(_fast_kde_2d)
wrapper(school, n_school)
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 0.13025 s
# File: <ipython-input-52-5d943c0e0f88>
# Function: _fast_kde_2d at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def _fast_kde_2d(x, y, gridsize=(128, 128), circular=False):
#      2         1         21.0     21.0      0.0      x = np.asarray(x, dtype=float)
#      3         1       1162.0   1162.0      0.9      x = x[np.isfinite(x)]
#      4         1         19.0     19.0      0.0      y = np.asarray(y, dtype=float)
#      5         1         31.0     31.0      0.0      y = y[np.isfinite(y)]
#      6
#      7         1        107.0    107.0      0.1      xmin, xmax = x.min(), x.max()
#      8         1         28.0     28.0      0.0      ymin, ymax = y.min(), y.max()
#      9
#     10         1          5.0      5.0      0.0      len_x = len(x)
#     11         1         38.0     38.0      0.0      weights = np.ones(len_x)
#     12         1          5.0      5.0      0.0      n_x, n_y = gridsize
#     13
#     14         1         11.0     11.0      0.0      d_x = (xmax - xmin) / (n_x - 1)
#     15         1          6.0      6.0      0.0      d_y = (ymax - ymin) / (n_y - 1)
#     16
#     17         1         73.0     73.0      0.1      xyi = np.vstack((x, y)).T
#     18         1         56.0     56.0      0.0      xyi -= [xmin, ymin]
#     19         1         41.0     41.0      0.0      xyi /= [d_x, d_y]
#     20         1         54.0     54.0      0.0      xyi = np.floor(xyi, xyi).T
#     21
#     22         1         10.0     10.0      0.0      scotts_factor = len_x ** (-1 / 6)
#     23         1       3450.0   3450.0      2.6      cov = np.cov(xyi)
#     24         1       1230.0   1230.0      0.9      std_devs = np.diag(cov ** 0.5)
#     25         1         58.0     58.0      0.0      kern_nx, kern_ny = np.round(scotts_factor * 2 * np.pi * std_devs)
#     26
#     27         1        146.0    146.0      0.1      inv_cov = np.linalg.inv(cov * scotts_factor ** 2)
#     28
#     29         1         36.0     36.0      0.0      x_x = np.arange(kern_nx) - kern_nx / 2
#     30         1         18.0     18.0      0.0      y_y = np.arange(kern_ny) - kern_ny / 2
#     31         1        315.0    315.0      0.2      x_x, y_y = np.meshgrid(x_x, y_y)
#     32
#     33         1         89.0     89.0      0.1      kernel = np.vstack((x_x.flatten(), y_y.flatten()))
#     34         1         68.0     68.0      0.1      kernel = np.dot(inv_cov, kernel) * kernel
#     35         1        144.0    144.0      0.1      kernel = np.exp(-kernel.sum(axis=0) / 2)
#     36         1         13.0     13.0      0.0      kernel = kernel.reshape((int(kern_ny), int(kern_nx)))
#     37
#     38         1          4.0      4.0      0.0      boundary = "wrap" if circular else "symm"
#     39
#     40         1       2320.0   2320.0      1.8      grid = coo_matrix((weights, xyi), shape=(n_x, n_y)).toarray()
#     41         1     120455.0 120455.0     92.5      grid = convolve2d(grid, kernel, mode="same", boundary=boundary)
#     42
#     43         1        158.0    158.0      0.1      norm_factor = np.linalg.det(2 * np.pi * cov * scotts_factor ** 2)
#     44         1         10.0     10.0      0.0      norm_factor = len_x * d_x * d_y * norm_factor ** 0.5
#     45
#     46         1         66.0     66.0      0.1      grid /= norm_factor
#     47
#     48         1          3.0      3.0      0.0      return grid, xmin, xmax, ymin, ymax
# /home/banzee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in sqrt

# %%
#Numba is not ideal for _fast_2d_kde

# %%
###############################################PLOT KHAT##################################################################

# %%
from arviz.plots import plot_khat

# %%
data = np.random.randn(1000000)

# %%
lp = LineProfiler()
wrapper = lp(plot_khat)
wrapper(data)
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 5.92775 s
# File: /home/banzee/Desktop/arviz/arviz/plots/khatplot.py
# Function: plot_khat at line 8
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      8                                           def plot_khat(
#      9                                               khats, figsize=None, textsize=None, markersize=None, ax=None, hlines_kwargs=None, **kwargs
#     10                                           ):
#     11                                               """
#     12                                               Plot Pareto tail indices.
#     13
#     14                                               Parameters
#     15                                               ----------
#     16                                               khats : array
#     17                                                   Pareto tail indices.
#     18                                               figsize : tuple
#     19                                                   Figure size. If None it will be defined automatically.
#     20                                               textsize: float
#     21                                                   Text size scaling factor for labels, titles and lines. If None it will be autoscaled based
#     22                                                   on figsize.
#     23                                               markersize: int
#     24                                                   markersize for scatter plot. Defaults to `None` in which case it will
#     25                                                   be chosen based on autoscaling for figsize.
#     26                                               ax: axes, opt
#     27                                                 Matplotlib axes
#     28                                               hlines_kwargs: dictionary
#     29                                                 Additional keywords passed to ax.hlines
#     30                                               kwargs :
#     31                                                 Additional keywords passed to ax.scatter
#     32
#     33                                               Returns
#     34                                               -------
#     35                                               ax : axes
#     36                                                 Matplotlib axes.
#     37
#     38                                               Examples
#     39                                               --------
#     40                                               Plot a default khat plot
#     41
#     42                                               .. plot::
#     43                                                   :context: close-figs
#     44
#     45                                                   >>> import arviz as az
#     46                                                   >>> centered_eight = az.load_arviz_data('centered_eight')
#     47                                                   >>> pareto_k = az.loo(centered_eight, pointwise=True)['pareto_k']
#     48                                                   >>> az.plot_khat(pareto_k)
#     49
#     50                                               """
#     51         1         10.0     10.0      0.0      if hlines_kwargs is None:
#     52         1          7.0      7.0      0.0          hlines_kwargs = {}
#     53
#     54         1          5.0      5.0      0.0      (figsize, ax_labelsize, _, xt_labelsize, linewidth, scaled_markersize) = _scale_fig_size(
#     55         1        256.0    256.0      0.0          figsize, textsize
#     56                                               )
#     57
#     58         1          7.0      7.0      0.0      if markersize is None:
#     59         1          4.0      4.0      0.0          markersize = scaled_markersize
#     60
#     61         1          3.0      3.0      0.0      if ax is None:
#     62         1    1240597.0 1240597.0     20.9          _, ax = plt.subplots(1, 1, figsize=figsize, constrained_layout=True)
#     63
#     64         1          4.0      4.0      0.0      ax.hlines(
#     65         1          2.0      2.0      0.0          [0, 0.5, 0.7, 1],
#     66         1          1.0      1.0      0.0          xmin=-1,
#     67         1          3.0      3.0      0.0          xmax=len(khats) + 1,
#     68         1          2.0      2.0      0.0          alpha=0.25,
#     69         1          2.0      2.0      0.0          linewidth=linewidth,
#     70         1     155404.0 155404.0      2.6          **hlines_kwargs
#     71                                               )
#     72
#     73         1       9448.0   9448.0      0.2      alphas = 0.5 + 0.5 * (khats > 0.5)
#     74         1         54.0     54.0      0.0      rgba_c = np.zeros((len(khats), 4))
#     75         1      20232.0  20232.0      0.3      rgba_c[:, 2] = 0.8
#     76         1       8513.0   8513.0      0.1      rgba_c[:, 3] = alphas
#     77         1    4441140.0 4441140.0     74.9      ax.scatter(np.arange(len(khats)), khats, c=rgba_c, marker="+", s=markersize, **kwargs)
#     78         1      27346.0  27346.0      0.5      ax.set_xlabel("Data point", fontsize=ax_labelsize)
#     79         1       5635.0   5635.0      0.1      ax.set_ylabel(r"Shape parameter κ", fontsize=ax_labelsize)
#     80         1      19069.0  19069.0      0.3      ax.tick_params(labelsize=xt_labelsize)
#     81         1          3.0      3.0      0.0      return ax

# %%
# Nothing to improve here :(

# %%
## PARALLEL PLOT, IMPROVE THE NP.STD in standard methods

# %%
### RAnk PLot

# %%
from arviz.plots import plot_rank
data = load_arviz_data("centered_eight")
data.posterior
# Out:
# <xarray.Dataset>
# Dimensions:  (chain: 4, draw: 500, school: 8)
# Coordinates:
#   * chain    (chain) int64 0 1 2 3
#   * draw     (draw) int64 0 1 2 3 4 5 6 7 8 ... 492 493 494 495 496 497 498 499
#   * school   (school) object 'Choate' 'Deerfield' ... "St. Paul's" 'Mt. Hermon'
# Data variables:
#     mu       (chain, draw) float64 ...
#     theta    (chain, draw, school) float64 ...
#     tau      (chain, draw) float64 ...
# Attributes:
#     created_at:                 2019-06-21T17:36:34.398087
#     inference_library:          pymc3
#     inference_library_version:  3.7

# %%
lp = LineProfiler()
wrapper = lp(plot_rank)
wrapper(data.posterior)
lp.print_stats()
# Out:
# Timer unit: 1e-06 s
#
# Total time: 14.1607 s
# File: /home/banzee/Desktop/arviz/arviz/plots/rankplot.py
# Function: plot_rank at line 38
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     38                                           def plot_rank(data, var_names=None, coords=None, bins=None, ref_line=True, figsize=None, axes=None):
#     39                                               """Plot rank order statistics of chains.
#     40
#     41                                               From the paper: Rank plots are histograms of the ranked posterior
#     42                                               draws (ranked over all chains) plotted separately for each chain.
#     43                                               If all of the chains are targeting the same posterior, we expect
#     44                                               the ranks in each chain to be uniform, whereas if one chain has a
#     45                                               different location or scale parameter, this will be reflected in
#     46                                               the deviation from uniformity. If rank plots of all chains look
#     47                                               similar, this indicates good mixing of the chains.
#     48
#     49                                               This plot was introduced by Aki Vehtari, Andrew Gelman, Daniel
#     50                                               Simpson, Bob Carpenter, Paul-Christian Burkner (2019):
#     51                                               Rank-normalization, folding, and localization: An improved R-hat
#     52                                               for assessing convergence of MCMC.
#     53                                               arXiv preprint https://arxiv.org/abs/1903.08008
#     54
#     55
#     56                                               Parameters
#     57                                               ----------
#     58                                               data : obj
#     59                                                   Any object that can be converted to an az.InferenceData object
#     60                                                   Refer to documentation of az.convert_to_dataset for details
#     61                                               var_names : string or list of variable names
#     62                                                   Variables to be plotted
#     63                                               coords : mapping, optional
#     64                                                   Coordinates of var_names to be plotted. Passed to `Dataset.sel`
#     65                                               bins : None or passed to np.histogram
#     66                                                   Binning strategy used for histogram. By default uses twice the
#     67                                                   result of Sturges' formula. See `np.histogram` documenation for
#     68                                                   other available arguments.
#     69                                               ref_line : boolean
#     70                                                   Whether to include a dashed line showing where a uniform
#     71                                                   distribution would lie
#     72                                               figsize : tuple
#     73                                                   Figure size. If None it will be defined automatically.
#     74                                               ax : axes
#     75                                                   Matplotlib axes. Defaults to None.
#     76
#     77                                               Returns
#     78                                               -------
#     79                                               ax : matplotlib axes
#     80
#     81                                               Examples
#     82                                               --------
#     83                                               Show a default rank plot
#     84
#     85                                               .. plot::
#     86                                                   :context: close-figs
#     87
#     88                                                   >>> import arviz as az
#     89                                                   >>> data = az.load_arviz_data('centered_eight')
#     90                                                   >>> az.plot_rank(data)
#     91
#     92                                               Recreate Figure 13 from the arxiv preprint
#     93
#     94                                               .. plot::
#     95                                                   :context: close-figs
#     96
#     97                                                   >>> import arviz as az
#     98                                                   >>> data = az.load_arviz_data('centered_eight')
#     99                                                   >>> az.plot_rank(data, var_names='tau')
#    100                                               """
#    101         1      29122.0  29122.0      0.2      posterior_data = convert_to_dataset(data, group="posterior")
#    102         1          9.0      9.0      0.0      if coords is not None:
#    103                                                   posterior_data = posterior_data.sel(**coords)
#    104         1      66322.0  66322.0      0.5      var_names = _var_names(var_names, posterior_data)
#    105         1    1052722.0 1052722.0      7.4      plotters = list(xarray_var_iter(posterior_data, var_names=var_names, combined=True))
#    106
#    107         1          4.0      4.0      0.0      if bins is None:
#    108                                                   # Use double Sturges' formula
#    109         1     153564.0 153564.0      1.1          bins = _sturges_formula(posterior_data, mult=2)
#    110
#    111         1          4.0      4.0      0.0      if axes is None:
#    112         1      78068.0  78068.0      0.6          rows, cols = default_grid(len(plotters))
#    113
#    114         1          9.0      9.0      0.0          figsize, ax_labelsize, titlesize, _, _, _ = _scale_fig_size(
#    115         1        168.0    168.0      0.0              figsize, None, rows=rows, cols=cols
#    116                                                   )
#    117         1    1225633.0 1225633.0      8.7          _, axes = _create_axes_grid(len(plotters), rows, cols, figsize=figsize, squeeze=False)
#    118
#    119        11         64.0      5.8      0.0      for ax, (var_name, selection, var_data) in zip(axes.ravel(), plotters):
#    120        10      98798.0   9879.8      0.7          ranks = scipy.stats.rankdata(var_data).reshape(var_data.shape)
#    121        10         37.0      3.7      0.0          all_counts = []
#    122        50        196.0      3.9      0.0          for row in ranks:
#    123        40      81166.0   2029.2      0.6              counts, bin_ary = np.histogram(row, bins=bins, range=(0, ranks.size))
#    124        40        175.0      4.4      0.0              all_counts.append(counts)
#    125        10        237.0     23.7      0.0          all_counts = np.array(all_counts)
#    126        10        285.0     28.5      0.0          gap = all_counts.max() * 1.05
#    127        10         44.0      4.4      0.0          width = bin_ary[1] - bin_ary[0]
#    128
#    129                                                   # Center the bins
#    130        10        137.0     13.7      0.0          bin_ary = (bin_ary[1:] + bin_ary[:-1]) / 2
#    131
#    132        10         34.0      3.4      0.0          y_ticks = []
#    133        50        307.0      6.1      0.0          for idx, counts in enumerate(all_counts):
#    134        40        185.0      4.6      0.0              y_ticks.append(idx * gap)
#    135        40        103.0      2.6      0.0              if ref_line:
#    136                                                           # Line where data is uniform
#    137        40     182574.0   4564.4      1.3                  ax.axhline(y=y_ticks[-1] + counts.mean(), linestyle="--", color="C1")
#    138                                                       # fake an x-axis
#    139        40     155071.0   3876.8      1.1              ax.axhline(y=y_ticks[-1], color="k", lw=1)
#    140        40        181.0      4.5      0.0              ax.bar(
#    141        40        102.0      2.5      0.0                  bin_ary,
#    142        40         91.0      2.3      0.0                  counts,
#    143        40        125.0      3.1      0.0                  bottom=y_ticks[-1],
#    144        40         93.0      2.3      0.0                  width=width,
#    145        40         89.0      2.2      0.0                  align="center",
#    146        40         89.0      2.2      0.0                  color="C0",
#    147        40   10939530.0 273488.2     77.3                  edgecolor=ax.get_facecolor(),
#    148                                                       )
#    149        10        747.0     74.7      0.0          ax.set_xlabel("Rank (all chains)", fontsize=ax_labelsize)
#    150        10        514.0     51.4      0.0          ax.set_ylabel("Chain", fontsize=ax_labelsize)
#    151        10      53310.0   5331.0      0.4          ax.set_yticks(y_ticks)
#    152        10       2254.0    225.4      0.0          ax.set_yticklabels(np.arange(len(y_ticks)))
#    153        10      38499.0   3849.9      0.3          ax.set_title(make_label(var_name, selection), fontsize=titlesize)
#    154
#    155         1          3.0      3.0      0.0      return axes

# %%
# Main bottleneck is ax.bar, however lets see the effect of numbafying histogram

# %%
"""Histograms of ranked posterior draws, plotted for each chain."""
import numpy as np
import scipy.stats

from arviz.data import convert_to_dataset
from arviz.plots.plot_utils import (
    _scale_fig_size,
    xarray_var_iter,
    default_grid,
    _create_axes_grid,
    make_label,
)
from arviz.utils import _var_names


def _sturges_formula(dataset, mult=1):
    return int(np.ceil(mult * np.log2(dataset.draw.size)) + 1)


def plot_rank(data, var_names=None, coords=None, bins=None, ref_line=True, figsize=None, axes=None):
    posterior_data = convert_to_dataset(data, group="posterior")
    if coords is not None:
        posterior_data = posterior_data.sel(**coords)
    var_names = _var_names(var_names, posterior_data)
    plotters = list(xarray_var_iter(posterior_data, var_names=var_names, combined=True))

    if bins is None:
        # Use double Sturges' formula
        bins = _sturges_formula(posterior_data, mult=2)

    if axes is None:
        rows, cols = default_grid(len(plotters))

        figsize, ax_labelsize, titlesize, _, _, _ = _scale_fig_size(
            figsize, None, rows=rows, cols=cols
        )
        _, axes = _create_axes_grid(len(plotters), rows, cols, figsize=figsize, squeeze=False)

    for ax, (var_name, selection, var_data) in zip(axes.ravel(), plotters):
        ranks = scipy.stats.rankdata(var_data).reshape(var_data.shape)
        all_counts = []
        for row in ranks:
            counts, bin_ary = np.histogram(row, bins=bins, range=(0, ranks.size))
            all_counts.append(counts)
        all_counts = np.array(all_counts)
        gap = all_counts.max() * 1.05
        width = bin_ary[1] - bin_ary[0]

        # Center the bins
        bin_ary = (bin_ary[1:] + bin_ary[:-1]) / 2

        y_ticks = []
        for idx, counts in enumerate(all_counts):
            y_ticks.append(idx * gap)
            if ref_line:
                # Line where data is uniform
                ax.axhline(y=y_ticks[-1] + counts.mean(), linestyle="--", color="C1")
            # fake an x-axis
            ax.axhline(y=y_ticks[-1], color="k", lw=1)
            ax.bar(
                bin_ary,
                counts,
                bottom=y_ticks[-1],
                width=width,
                align="center",
                color="C0",
                edgecolor=ax.get_facecolor(),
            )
        ax.set_xlabel("Rank (all chains)", fontsize=ax_labelsize)
        ax.set_ylabel("Chain", fontsize=ax_labelsize)
        ax.set_yticks(y_ticks)
        ax.set_yticklabels(np.arange(len(y_ticks)))
        ax.set_title(make_label(var_name, selection), fontsize=titlesize)

    return axes

def plot_rank_jit(data, var_names=None, coords=None, bins=None, ref_line=True, figsize=None, axes=None):
    posterior_data = convert_to_dataset(data, group="posterior")
    if coords is not None:
        posterior_data = posterior_data.sel(**coords)
    var_names = _var_names(var_names, posterior_data)
    plotters = list(xarray_var_iter(posterior_data, var_names=var_names, combined=True))

    if bins is None:
        # Use double Sturges' formula
        bins = _sturges_formula(posterior_data, mult=2)

    if axes is None:
        rows, cols = default_grid(len(plotters))

        figsize, ax_labelsize, titlesize, _, _, _ = _scale_fig_size(
            figsize, None, rows=rows, cols=cols
        )
        _, axes = _create_axes_grid(len(plotters), rows, cols, figsize=figsize, squeeze=False)

    for ax, (var_name, selection, var_data) in zip(axes.ravel(), plotters):
        ranks = scipy.stats.rankdata(var_data).reshape(var_data.shape)
        all_counts = []
        for row in ranks:
            counts, bin_ary = histogram(row, bins=bins, range=(0, ranks.size))
            all_counts.append(counts)
        all_counts = np.array(all_counts)
        gap = all_counts.max() * 1.05
        width = bin_ary[1] - bin_ary[0]

        # Center the bins
        bin_ary = (bin_ary[1:] + bin_ary[:-1]) / 2

        y_ticks = []
        for idx, counts in enumerate(all_counts):
            y_ticks.append(idx * gap)
            if ref_line:
                # Line where data is uniform
                ax.axhline(y=y_ticks[-1] + counts.mean(), linestyle="--", color="C1")
            # fake an x-axis
            ax.axhline(y=y_ticks[-1], color="k", lw=1)
            ax.bar(
                bin_ary,
                counts,
                bottom=y_ticks[-1],
                width=width,
                align="center",
                color="C0",
                edgecolor=ax.get_facecolor(),
            )
        ax.set_xlabel("Rank (all chains)", fontsize=ax_labelsize)
        ax.set_ylabel("Chain", fontsize=ax_labelsize)
        ax.set_yticks(y_ticks)
        ax.set_yticklabels(np.arange(len(y_ticks)))
        ax.set_title(make_label(var_name, selection), fontsize=titlesize)

    return axes

@conditional_jit
def histogram(row, bins, range):
    return np.histogram(row, bins, range)

# %%
# %timeit(plot_rank(data.posterior))
# Out:
# 1.04 s ± 31.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit(plot_rank_jit(data.posterior))
# Out:
# 1.2 s ± 137 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Strange
